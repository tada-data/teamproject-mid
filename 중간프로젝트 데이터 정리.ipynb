# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

import matplotlib.font_manager as fm
font_name = fm.FontProperties(fname = "C:/Windows/Fonts/malgun.ttf").get_name()
plt.rc("font", family= font_name)

import matplotlib as mlp
mlp.rcParams["axes.unicode_minus"] = False

# %%
OTT = pd.read_excel("data/가장많이이용하는OTT서비스(20-21).xlsx", header=[0,1], index_col=[0,1])
OTT
# Out:
# C:\Users\gyeoa\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 구분별(2)        2020                                                         \
# 구분별(2)     사례수 (명) TV 방송 프로그램 (VOD/다시보기) (%) 해외 TV 방송 프로그램 (%) 실시간 TV (%)
# 전체 소계       7434.0                      57.0               5.3       24.5
# 성별 남        3872.0                      54.9               5.5       24.9
#    여        3562.0                      59.2               4.9       24.0
# 연령 만10대미만    173.0                      24.9               0.0       12.3
#    만10-19세   825.0                      48.6               2.6       18.3
#    만20-29세  1378.0                      62.6               8.7       27.1
#    만30-39세  1420.0                      57.8               7.5       32.1
#    만40-49세  1481.0                      64.9               5.4       25.2
# ...

# %%
OTT.columns =[["2020","2020","2020","2020","2020","2020","2020","2020","2020","2021","2021","2021","2021","2021","2021","2021","2021","2021","2021"], ["사례수","국내TV", "해외TV", "실시간TV", "영화", "OTT자체제작", "개인방송(예능/오락)", "음악", "기타","사례수", "영화", "개인방송(예능/오락)", "드라마","교양/다큐","교육/학습","애니메이션","스포츠","뉴스","기타"]]

# %%
OTT
# Out:
#               2020                                                        \
#                사례수  국내TV 해외TV 실시간TV    영화 OTT자체제작 개인방송(예능/오락)    음악   기타
# 전체 소계       7434.0  57.0  5.3  24.5  22.3    19.8        73.1  32.1  0.3
# 성별 남        3872.0  54.9  5.5  24.9  23.9    20.4        75.2  30.3  0.4
#    여        3562.0  59.2  4.9  24.0  20.6    19.1        70.8  34.1  0.3
# 연령 만10대미만    173.0  24.9  0.0  12.3   3.2     9.7        85.7  19.8  1.0
#    만10-19세   825.0  48.6  2.6  18.3  15.9    12.9        79.6  40.4  0.9
#    만20-29세  1378.0  62.6  8.7  27.1  34.8    23.9        73.7  34.1  0.3
#    만30-39세  1420.0  57.8  7.5  32.1  30.6    28.2        69.6  30.8  0.1
#    만40-49세  1481.0  64.9  5.4  25.2  23.6    19.4        69.2  32.0  0.4
#    만50-59세  1373.0  55.3  3.3  21.4  14.8    16.8        73.9  30.0  0.3
#    만60-69세   666.0  49.9  2.1  19.2   7.9    12.9        74.4  31.5  0.2
#    만70세이상    119.0  46.9  3.0  19.5   3.5    10.3        76.0  15.2  0.0
#
# ...

# %%
twooTV = OTT["2020"]["국내TV"] + OTT["2020"]["해외TV"]+OTT["2020"]["실시간TV"]

# %%
twotwoTV = OTT["2021"]["드라마"] + OTT["2021"]["교양/다큐"]+OTT["2021"]["교육/학습"]

# %%
twooTV
# Out:
# 전체  소계         86.8
# 성별  남          85.3
#     여          88.1
# 연령  만10대미만     37.2
#     만10-19세    69.5
#     만20-29세    98.4
#     만30-39세    97.4
#     만40-49세    95.5
#     만50-59세    80.0
#     만60-69세    71.2
#     만70세이상     69.4
# dtype: float64

# %%
TV = pd.DataFrame([twooTV, twotwoTV], index=["2020","2021"]).T

# %%
TV
# Out:
#             2020  2021
# 전체 소계       86.8  75.8
# 성별 남        85.3  62.2
#    여        88.1  90.4
# 연령 만10대미만   37.2  58.2
#    만10-19세  69.5  79.6
#    만20-29세  98.4  85.8
#    만30-39세  97.4  78.2
#    만40-49세  95.5  76.0
#    만50-59세  80.0  71.5
#    만60-69세  71.2  70.0
#    만70세이상   69.4  60.3

# %%
movie = pd.DataFrame([OTT["2020"]["영화"], OTT["2021"]["영화"]], index=["2020","2021"]).T

# %%
movie
# Out:
#             2020  2021
# 전체 소계       22.3  38.5
# 성별 남        23.9  37.4
#    여        20.6  39.8
# 연령 만10대미만    3.2   8.1
#    만10-19세  15.9  30.7
#    만20-29세  34.8  61.5
#    만30-39세  30.6  46.9
#    만40-49세  23.6  45.1
#    만50-59세  14.8  29.8
#    만60-69세   7.9  18.1
#    만70세이상    3.5  13.5

# %%
TV
# Out:
#             2020  2021
# 전체 소계       86.8  75.8
# 성별 남        85.3  62.2
#    여        88.1  90.4
# 연령 만10대미만   37.2  58.2
#    만10-19세  69.5  79.6
#    만20-29세  98.4  85.8
#    만30-39세  97.4  78.2
#    만40-49세  95.5  76.0
#    만50-59세  80.0  71.5
#    만60-69세  71.2  70.0
#    만70세이상   69.4  60.3

# %%
개인방송 = pd.DataFrame([OTT["2020"]["개인방송(예능/오락)"], OTT["2021"]["개인방송(예능/오락)"]], index=["2020","2021"]).T

# %%
개인방송
# Out:
#             2020  2021
# 전체 소계       73.1  80.5
# 성별 남        75.2  78.6
#    여        70.8  82.5
# 연령 만10대미만   85.7  71.3
#    만10-19세  79.6  88.8
#    만20-29세  73.7  88.7
#    만30-39세  69.6  86.4
#    만40-49세  69.2  79.8
#    만50-59세  73.9  75.2
#    만60-69세  74.4  69.6
#    만70세이상   76.0  64.2
