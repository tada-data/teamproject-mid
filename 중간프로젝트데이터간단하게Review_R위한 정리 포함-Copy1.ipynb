# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

import matplotlib.font_manager as fm
font_name = fm.FontProperties(fname = "C:/Windows/Fonts/malgun.ttf").get_name()
plt.rc("font", family= font_name)

import matplotlib as mlp
mlp.rcParams["axes.unicode_minus"] = False

# %% [markdown]
# ## OTT 서비스 중 영화를 이용하는 사람들의 증가 비율

# %%
OTT = pd.read_excel("가장많이이용하는OTT서비스_20-21.xlsx", header=[0,1], index_col=[0,1])
OTT
# Out:
# C:\Users\gyeoa\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 구분별(2)        2020                                                         \
# 구분별(2)     사례수 (명) TV 방송 프로그램 (VOD/다시보기) (%) 해외 TV 방송 프로그램 (%) 실시간 TV (%)
# 전체 소계       7434.0                      57.0               5.3       24.5
# 성별 남        3872.0                      54.9               5.5       24.9
#    여        3562.0                      59.2               4.9       24.0
# 연령 만10대미만    173.0                      24.9               0.0       12.3
#    만10-19세   825.0                      48.6               2.6       18.3
#    만20-29세  1378.0                      62.6               8.7       27.1
#    만30-39세  1420.0                      57.8               7.5       32.1
#    만40-49세  1481.0                      64.9               5.4       25.2
#    만50-59세  1373.0                      55.3               3.3       21.4
#    만60-69세   666.0                      49.9               2.1       19.2
#    만70세이상    119.0                      46.9               3.0       19.5
#
# 구분별(2)                                                                        \
# 구분별(2)     영화 (%) OTT 사업자 자체 제작 프로그램(넷플릭스 오리지널 등) (%) 예능/오락(개인방송 콘텐츠 포함) (%)
# 전체 소계        22.3                                19.8                   73.1
# 성별 남         23.9                                20.4                   75.2
#    여         20.6                                19.1                   70.8
# 연령 만10대미만     3.2                                 9.7                   85.7
#    만10-19세   15.9                                12.9                   79.6
#    만20-29세   34.8                                23.9                   73.7
#    만30-39세   30.6                                28.2                   69.6
#    만40-49세   23.6                                19.4                   69.2
#    만50-59세   14.8                                16.8                   73.9
#    만60-69세    7.9                                12.9                   74.4
#    만70세이상     3.5                                10.3                   76.0
#
# 구분별(2)                      2021                                        \
# 구분별(2)     음악 (%) 기타 (%) 사례수 (명) 영화 (%) 예능/오락(개인방송 콘텐츠 포함) (%) 드라마 (%)
# 전체 소계        32.1    0.3  8293.7   38.5                   80.5    47.0
# 성별 남         30.3    0.4  4283.5   37.4                   78.6    33.2
#    여         34.1    0.3  4010.2   39.8                   82.5    61.7
# 연령 만10대미만    19.8    1.0   174.5    8.1                   71.3     7.1
#    만10-19세   40.4    0.9   880.1   30.7                   88.8    31.1
#    만20-29세   34.1    0.3  1381.4   61.5                   88.7    57.0
#    만30-39세   30.8    0.1  1390.1   46.9                   86.4    53.2
#    만40-49세   32.0    0.4  1585.9   45.1                   79.8    52.7
#    만50-59세   30.0    0.3  1580.6   29.8                   75.2    45.8
#    만60-69세   31.5    0.2  1025.7   18.1                   69.6    42.7
#    만70세이상    15.2    0.0   275.5   13.5                   64.2    31.5
#
# 구분별(2)
# 구분별(2)     교양/다큐멘터리 (%) 교육/학습 (%) 애니메이션(만화) (%) 스포츠 (%) 뉴스 (%) 기타 (%)
# 전체 소계              19.6       9.2          10.2    23.4   25.8    2.0
# 성별 남               20.6       8.4           9.3    39.9   29.7    1.7
#    여               18.6      10.1          11.2     5.8   21.6    2.2
# 연령 만10대미만           9.3      41.8          72.9     0.3    0.9    0.0
#    만10-19세         12.4      36.1          39.1     9.9    5.1    1.6
#    만20-29세         19.9       8.9          10.5    22.7   11.3    0.9
#    만30-39세         19.1       5.9           8.6    29.9   21.1    1.8
#    만40-49세         18.6       4.7           4.6    26.8   29.5    1.7
#    만50-59세         21.4       4.3           1.5    28.3   36.1    2.6
#    만60-69세         25.4       1.9           1.0    20.7   45.5    2.9
#    만70세이상          25.6       3.2           1.4    15.3   48.9    4.3

# %%
OTT.columns =[["2020","2020","2020","2020","2020","2020","2020","2020","2020","2021","2021","2021","2021","2021","2021","2021","2021","2021","2021"], ["사례수","국내TV", "해외TV", "실시간TV", "영화", "OTT자체제작", "개인방송(예능/오락)", "음악", "기타","사례수", "영화", "개인방송(예능/오락)", "드라마","교양/다큐","교육/학습","애니메이션","스포츠","뉴스","기타"]]

# %%
OTT
# Out:
#               2020                                                        \
#                사례수  국내TV 해외TV 실시간TV    영화 OTT자체제작 개인방송(예능/오락)    음악   기타
# 전체 소계       7434.0  57.0  5.3  24.5  22.3    19.8        73.1  32.1  0.3
# 성별 남        3872.0  54.9  5.5  24.9  23.9    20.4        75.2  30.3  0.4
#    여        3562.0  59.2  4.9  24.0  20.6    19.1        70.8  34.1  0.3
# 연령 만10대미만    173.0  24.9  0.0  12.3   3.2     9.7        85.7  19.8  1.0
#    만10-19세   825.0  48.6  2.6  18.3  15.9    12.9        79.6  40.4  0.9
#    만20-29세  1378.0  62.6  8.7  27.1  34.8    23.9        73.7  34.1  0.3
#    만30-39세  1420.0  57.8  7.5  32.1  30.6    28.2        69.6  30.8  0.1
#    만40-49세  1481.0  64.9  5.4  25.2  23.6    19.4        69.2  32.0  0.4
#    만50-59세  1373.0  55.3  3.3  21.4  14.8    16.8        73.9  30.0  0.3
#    만60-69세   666.0  49.9  2.1  19.2   7.9    12.9        74.4  31.5  0.2
#    만70세이상    119.0  46.9  3.0  19.5   3.5    10.3        76.0  15.2  0.0
#
#               2021
#                사례수    영화 개인방송(예능/오락)   드라마 교양/다큐 교육/학습 애니메이션   스포츠    뉴스   기타
# 전체 소계       8293.7  38.5        80.5  47.0  19.6   9.2  10.2  23.4  25.8  2.0
# 성별 남        4283.5  37.4        78.6  33.2  20.6   8.4   9.3  39.9  29.7  1.7
#    여        4010.2  39.8        82.5  61.7  18.6  10.1  11.2   5.8  21.6  2.2
# 연령 만10대미만    174.5   8.1        71.3   7.1   9.3  41.8  72.9   0.3   0.9  0.0
#    만10-19세   880.1  30.7        88.8  31.1  12.4  36.1  39.1   9.9   5.1  1.6
#    만20-29세  1381.4  61.5        88.7  57.0  19.9   8.9  10.5  22.7  11.3  0.9
#    만30-39세  1390.1  46.9        86.4  53.2  19.1   5.9   8.6  29.9  21.1  1.8
#    만40-49세  1585.9  45.1        79.8  52.7  18.6   4.7   4.6  26.8  29.5  1.7
#    만50-59세  1580.6  29.8        75.2  45.8  21.4   4.3   1.5  28.3  36.1  2.6
#    만60-69세  1025.7  18.1        69.6  42.7  25.4   1.9   1.0  20.7  45.5  2.9
#    만70세이상    275.5  13.5        64.2  31.5  25.6   3.2   1.4  15.3  48.9  4.3

# %%
#OTT["시청증가율"] = OTT["2021"]["사례수"]/OTT["2020"]["사례수"] *100
# 사례수가 표본 수이므로 다른 자료 가져오기

# %% [markdown]
# ### OTT서비스 이용 여부

# %%
user = pd.read_excel("최근3개월OTT서비스이용경험.xlsx", header=[0,1], index_col=[0,1])
user
# Out:
# C:\Users\gyeoa\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 구분별(2)         2019                             2020                          \
# 구분별(2)      사례수 (명) 이용경험 있음 (%) 이용경험 없음 (%)  사례수 (명) 이용경험 있음 (%) 이용경험 없음 (%)
# 전체 소계       10864.0        41.0        59.0  10302.0        72.2        27.8
# 성별 남         5401.1        44.0        56.0   5146.0        75.2        24.8
#    여         5462.9        38.1        61.9   5156.0        69.1        30.9
# 연령 만10대미만     346.5        23.3        76.7    258.0        67.1        32.9
#    만10-19세   1036.2        48.4        51.6    984.0        83.8        16.2
#    만20-29세   1564.4        65.4        34.6   1440.0        95.7         4.3
#    만30-39세   1578.3        62.0        38.0   1509.0        94.1         5.9
#    만40-49세   1838.3        47.2        52.8   1745.0        84.9        15.1
#    만50-59세   1924.9        35.5        64.5   1827.0        75.2        24.8
#    만60-69세   1383.8        19.8        80.2   1377.0        48.3        51.7
#    만70세이상    1191.6         4.1        95.9   1162.0        10.3        89.7
#
# 구분별(2)         2021
# 구분별(2)      사례수 (명) 이용경험 있음 (%) 이용경험 없음 (%)
# 전체 소계       10154.0        81.7        18.3
# 성별 남         5061.2        84.6        15.4
#    여         5092.8        78.7        21.3
# 연령 만10대미만     226.1        77.2        22.8
#    만10-19세    962.7        91.4         8.6
#    만20-29세   1411.4        97.9         2.1
#    만30-39세   1441.2        96.5         3.5
#    만40-49세   1694.0        93.6         6.4
#    만50-59세   1788.0        88.4        11.6
#    만60-69세   1453.5        70.6        29.4
#    만70세이상    1177.2        23.4        76.6

# %%
# 영화 시청 증가율과 비교하기 위해 2020년과 2021년만 비교
userincrease = pd.DataFrame(round((user["2021"]["이용경험 있음 (%)"]-user["2020"]["이용경험 있음 (%)"])/user["2020"]["이용경험 있음 (%)"] *100,2))
userincrease.columns = ["이용자증가율"]
userincrease
# OTT이용경험이 있는 비율이 전 연령대에서 2020년에 비해 모두 증가하였다(최소 1.02에서 2.27까지)
# Out:
#             이용자증가율
# 전체 소계        13.16
# 성별 남         12.50
#    여         13.89
# 연령 만10대미만    15.05
#    만10-19세    9.07
#    만20-29세    2.30
#    만30-39세    2.55
#    만40-49세   10.25
#    만50-59세   17.55
#    만60-69세   46.17
#    만70세이상   127.18

# %%
users = pd.DataFrame({"2021OTT이용경험": user["2021"]["이용경험 있음 (%)"], "2020OTT이용경험" : user["2020"]["이용경험 있음 (%)"]})
# users = users.reset_index()
# users = users.iloc[:, 1:]
#users.columns = ["group", "2021user", "2020user"]
users1 = users
users = users.droplevel(level=0).T
users1 = users1.droplevel(level=0).reset_index()
users1
users["년도"]= [1,0]
users
# Out:
#                소계     남     여  만10대미만  만10-19세  만20-29세  만30-39세  만40-49세  \
# 2021OTT이용경험  81.7  84.6  78.7    77.2     91.4     97.9     96.5     93.6
# 2020OTT이용경험  72.2  75.2  69.1    67.1     83.8     95.7     94.1     84.9
#
#              만50-59세  만60-69세  만70세이상  년도
# 2021OTT이용경험     88.4     70.6    23.4   1
# 2020OTT이용경험     75.2     48.3    10.3   0

# %%
users1
# Out:
#       index  2021OTT이용경험  2020OTT이용경험
# 0        소계         81.7         72.2
# 1         남         84.6         75.2
# 2         여         78.7         69.1
# 3    만10대미만         77.2         67.1
# 4   만10-19세         91.4         83.8
# 5   만20-29세         97.9         95.7
# 6   만30-39세         96.5         94.1
# 7   만40-49세         93.6         84.9
# 8   만50-59세         88.4         75.2
# 9   만60-69세         70.6         48.3
# 10   만70세이상         23.4         10.3

# %%
users2 = users1.melt(id_vars = "index", value_vars=["2021OTT이용경험","2020OTT이용경험"])
users2
# Out:
#       index     variable  value
# 0        소계  2021OTT이용경험   81.7
# 1         남  2021OTT이용경험   84.6
# 2         여  2021OTT이용경험   78.7
# 3    만10대미만  2021OTT이용경험   77.2
# 4   만10-19세  2021OTT이용경험   91.4
# 5   만20-29세  2021OTT이용경험   97.9
# 6   만30-39세  2021OTT이용경험   96.5
# 7   만40-49세  2021OTT이용경험   93.6
# 8   만50-59세  2021OTT이용경험   88.4
# 9   만60-69세  2021OTT이용경험   70.6
# 10   만70세이상  2021OTT이용경험   23.4
# 11       소계  2020OTT이용경험   72.2
# 12        남  2020OTT이용경험   75.2
# 13        여  2020OTT이용경험   69.1
# 14   만10대미만  2020OTT이용경험   67.1
# 15  만10-19세  2020OTT이용경험   83.8
# 16  만20-29세  2020OTT이용경험   95.7
# 17  만30-39세  2020OTT이용경험   94.1
# 18  만40-49세  2020OTT이용경험   84.9
# 19  만50-59세  2020OTT이용경험   75.2
# 20  만60-69세  2020OTT이용경험   48.3
# 21   만70세이상  2020OTT이용경험   10.3

# %%
year=[]
for i in range(22):
    if users2["variable"][i] == "2021OTT이용경험":
        year.append(1)
    else:
        year.append(0)

users2["year"]=year
users2
# Out:
#       index     variable  value  year
# 0        소계  2021OTT이용경험   81.7     1
# 1         남  2021OTT이용경험   84.6     1
# 2         여  2021OTT이용경험   78.7     1
# 3    만10대미만  2021OTT이용경험   77.2     1
# 4   만10-19세  2021OTT이용경험   91.4     1
# 5   만20-29세  2021OTT이용경험   97.9     1
# 6   만30-39세  2021OTT이용경험   96.5     1
# 7   만40-49세  2021OTT이용경험   93.6     1
# 8   만50-59세  2021OTT이용경험   88.4     1
# 9   만60-69세  2021OTT이용경험   70.6     1
# 10   만70세이상  2021OTT이용경험   23.4     1
# 11       소계  2020OTT이용경험   72.2     0
# 12        남  2020OTT이용경험   75.2     0
# 13        여  2020OTT이용경험   69.1     0
# 14   만10대미만  2020OTT이용경험   67.1     0
# 15  만10-19세  2020OTT이용경험   83.8     0
# 16  만20-29세  2020OTT이용경험   95.7     0
# 17  만30-39세  2020OTT이용경험   94.1     0
# 18  만40-49세  2020OTT이용경험   84.9     0
# 19  만50-59세  2020OTT이용경험   75.2     0
# 20  만60-69세  2020OTT이용경험   48.3     0
# 21   만70세이상  2020OTT이용경험   10.3     0

# %%
users.to_csv("users.csv", index=False)

# %%
users1.to_csv("users1.csv", index=False)

# %%
users2.to_csv("users2.csv", index=False)

# %% [markdown]
# ## OTT서비스를 이용한 영화시청증가율과 개인방송시청증가율

# %%
# OTT시청의 증감률을 확인하고 우리가 알아보고자 하는 OTT에서 영화를 보는 시청 증감률이 차이를 비교하기 위해 dataframe을 합쳐준다
# 추가로 2020년과 2021년의 공통 컬럼인 개인방송부분도 추가해서 비교하겠다.

# %%
OTT_movie = pd.DataFrame([OTT["2020"]["영화"], OTT["2021"]["영화"]], index=["2020","2021"]).T
OTT_movie["OTT영화시청증가율"]=(OTT_movie["2021"]-OTT_movie["2020"])/OTT_movie["2020"]*100
OTT_movie
# Out:
#             2020  2021  OTT영화시청증가율
# 전체 소계       22.3  38.5   72.645740
# 성별 남        23.9  37.4   56.485356
#    여        20.6  39.8   93.203883
# 연령 만10대미만    3.2   8.1  153.125000
#    만10-19세  15.9  30.7   93.081761
#    만20-29세  34.8  61.5   76.724138
#    만30-39세  30.6  46.9   53.267974
#    만40-49세  23.6  45.1   91.101695
#    만50-59세  14.8  29.8  101.351351
#    만60-69세   7.9  18.1  129.113924
#    만70세이상    3.5  13.5  285.714286

# %%
OTT_개인방송 = pd.DataFrame([OTT["2020"]["개인방송(예능/오락)"], OTT["2021"]["개인방송(예능/오락)"]], index=["2020","2021"]).T
OTT_개인방송["OTT개인방송시청증가율"]=(OTT_개인방송["2021"]-OTT_개인방송["2020"])/OTT_개인방송["2020"]*100
OTT_개인방송
# Out:
#             2020  2021  OTT개인방송시청증가율
# 전체 소계       73.1  80.5     10.123119
# 성별 남        75.2  78.6      4.521277
#    여        70.8  82.5     16.525424
# 연령 만10대미만   85.7  71.3    -16.802800
#    만10-19세  79.6  88.8     11.557789
#    만20-29세  73.7  88.7     20.352782
#    만30-39세  69.6  86.4     24.137931
#    만40-49세  69.2  79.8     15.317919
#    만50-59세  73.9  75.2      1.759134
#    만60-69세  74.4  69.6     -6.451613
#    만70세이상   76.0  64.2    -15.526316

# %%
change = pd.concat([OTT_movie["OTT영화시청증가율"], userincrease["이용자증가율"], OTT_개인방송["OTT개인방송시청증가율"]], axis=1)
change
# Out:
#             OTT영화시청증가율  이용자증가율  OTT개인방송시청증가율
# 전체 소계        72.645740   13.16     10.123119
# 성별 남         56.485356   12.50      4.521277
#    여         93.203883   13.89     16.525424
# 연령 만10대미만   153.125000   15.05    -16.802800
#    만10-19세   93.081761    9.07     11.557789
#    만20-29세   76.724138    2.30     20.352782
#    만30-39세   53.267974    2.55     24.137931
#    만40-49세   91.101695   10.25     15.317919
#    만50-59세  101.351351   17.55      1.759134
#    만60-69세  129.113924   46.17     -6.451613
#    만70세이상   285.714286  127.18    -15.526316

# %%
# OTT전체시청증감률 대비 OTT영화시청증감률을 비교한다. 

moviechange = change["OTT영화시청증가율"]/change["이용자증가율"] 
print(round(np.mean(moviechange),2))
# 전체적으로 OTT시청하는 사람들의 사례수가 증가한 추세인데, OTT에서 영화를 보는 사람들은 OTT전체 이용률대비에도 평균적으로 10.1배 높다. 

personal = change["OTT개인방송시청증가율"]/change["이용자증가율"] 
print(round(np.mean(personal),2))
# 한편 공통 컬럼으로 비교하고자 했던 개인방송을 시청하는 사람들은 OTT전체 이용률 대비 2.01배이다.

result = pd.DataFrame(pd.concat([moviechange, personal], axis=1))
result.columns=["전체이용자증가율대비 영화시청증가율", "전체이용자증가율대비 개인방송시청증가율"]
result
# Out:
# 10.1
# 2.01
#             전체이용자증가율대비 영화시청증가율  전체이용자증가율대비 개인방송시청증가율
# 전체 소계                 5.520193              0.769234
# 성별 남                  4.518828              0.361702
#    여                  6.710143              1.189735
# 연령 만10대미만            10.174419             -1.116465
#    만10-19세           10.262598              1.274288
#    만20-29세           33.358321              8.849035
#    만30-39세           20.889402              9.465855
#    만40-49세            8.887970              1.494431
#    만50-59세            5.775006              0.100236
#    만60-69세            2.796490             -0.139736
#    만70세이상             2.246535             -0.122081

# %%
# OTT로 영화를 보는 사람들의 수가 많이 늘었음을 다시 한번 확인할 수 있다.

# %% [markdown]
# ## 여가시간에 영화관을 가장 많이 이용한 사람들 비율

# %%
sparemovie= pd.read_csv("1년동안가장많이이용한여가공간1순위_영화관비율.csv", encoding="euc-kr", header=[0,1], index_col=[0,1])

# %%
sparemovie
# Out:
# 통계분류(1)         2016  2018  2019 2020 2021
# 통계분류(1)          영화관   영화관   영화관  영화관  영화관
# 전체      소계       4.4   6.8   9.4    3  2.1
# 성별      남성       4.2   6.1   8.9    3  2.1
#         여성       4.6   7.5   9.9    3    2
# 연령별     15~19세   7.3  10.3  17.3  6.1  4.4
#         20대     10.1  12.6  16.5  6.2    4
# ...              ...   ...   ...  ...  ...
# 17개 시도별 경남       4.1   7.1   8.4  1.3  0.2
#         제주       7.0   9.8   7.9    -  0.3
# 장애여부별   장애등록     0.0   7.5   8.3  1.5  0.5
#         미등록      0.0   5.3     5  2.9    -
#         해당사항없음   0.0   6.8   9.4  3.1  2.1
#
# [67 rows x 5 columns]

# %%
#위의 OTT 시청자 구분 맞춰주기(전체, 성별, 연령별)

sparetheater = sparemovie.loc[["전체","성별","연령별"],["2020","2021"]]

# %%
sparetheater.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 10 entries, ('전체', '소계') to ('연령별', '70세이상')
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   (2020, 영화관)  10 non-null     object
#  1   (2021, 영화관)  10 non-null     object
# dtypes: object(2)
# memory usage: 3.4+ KB

# %%
sparetheater = sparetheater.astype(float)

# %%
sparetheater["여가영화증감률"]=(sparetheater["2021"]-sparetheater["2020"])/sparetheater["2020"]*100
sparetheater
# Out:
# 통계분류(1)    2020 2021    여가영화증감률
# 통계분류(1)     영화관  영화관
# 전체  소계      3.0  2.1 -30.000000
# 성별  남성      3.0  2.1 -30.000000
#     여성      3.0  2.0 -33.333333
# 연령별 15~19세  6.1  4.4 -27.868852
#     20대     6.2  4.0 -35.483871
#     30대     4.3  4.2  -2.325581
#     40대     3.1  1.4 -54.838710
#     50대     1.8  1.2 -33.333333
#     60대     0.8  0.4 -50.000000
#     70세이상   0.3  0.4  33.333333

# %%
#1년동안 가장 많이 이용한 여가공간으로 영화관을 뽑은 사람들은 70세이상을 제외하고 모두 줄어들었다.

# %%
Rmovie = OTT_movie[["OTT영화시청증가율"]].droplevel(level=0).T
Rmovie.columns = ["소계","남성","여성","10대1","10대2","20대","30대","40대","50대","60대","70세이상"]
Rmovie = Rmovie.drop(["10대1","10대2"], axis="columns")
Rmovie["10대"] = 97.080292
Rmovie = Rmovie.T

# %%
Rsparetheater = sparetheater[["여가영화증감률"]].droplevel(level=0).T
Rsparetheater.columns = ["소계","남성","여성","10대","20대","30대","40대","50대","60대","70세이상"]
Rsparetheater = Rsparetheater.T

# %%
moviechange = pd.DataFrame({"OTT영화시청증감률": Rmovie["OTT영화시청증가율"], "여가영화관증감률" : Rsparetheater["여가영화증감률"]})
moviechange = moviechange.reset_index()

# %%
moviechange.to_csv("moviechange.csv", index=False)

# %% [markdown]
# ## 영화 관객수 증가 비율

# %%
movietheater = pd.read_excel("영화관객수및매출액_2018-2022.xlsx", header=[0,1], index_col=[0])

# %%
#movietheater = movietheater.droplevel(axis=1, level=0).T

# %%
theater = pd.DataFrame(movietheater["전체"]["관객수"])

# %%
afterone = (theater.loc[2021]-theater.loc[2020])/theater.loc[2020]
# 2020년 대비 약간 늘긴했지만 거의 비슷하다고 볼 수 있다. 

beforeafter = (theater.loc[2020]-theater.loc[2019])/theater.loc[2019]
# 영화관관람객수는 사실 2019년 대비해서 많이 줄고 2020년과 2021년은 비슷하다. 

print("2021년 : ", afterone, "\n", "2020년 : ", beforeafter)
# Out:
# 2021년 :  관객수    0.01692
# dtype: float64
#  2020년 :  관객수   -0.737408
# dtype: float64

# %%
theater
# Out:
#              관객수
# 2018   216385269
# 2019   226678777
# 2020    59523967
# 2021    60531087
# 2022    92501405
# 합계    3032329696

# %% [markdown]
# ## OTT서비스관련 어플리케이션을 자주 이용하는 사람들의 비율 증가 확인

# %%
application = pd.read_csv("자주사용하는앱.csv", header=[0,1], index_col=[0,1])

# %%
application
# Out:
# 구분별(1)                  2017                                \
# 구분별(1)                게임 (%) 소셜네트워킹(카카오스토리 페이스북 트위터 등) (%)
# 전체      소계              24.0                          20.2
# 성별      남               31.5                          18.1
#         여               16.1                          22.4
# 연령      만10대미만          52.2                          13.4
#         만10-19세         51.3                          29.1
# ...                      ...                           ...
# 가구주와의관계 부모(배우자부모포함)      0.6                           0.0
#         조부모(배우자조부모포함)      -                             -
#         형제자매/그배우자       52.1                          20.1
#         기타친인척           12.6                           7.2
#         동거인             22.1                          11.1
#
# 구분별(1)                                                           \
# 구분별(1)                인스턴트메신저(카카오톡 라인 페이스북 등의 SNS 자체 메신저 등) (%)
# 전체      소계                                                 62.0
# 성별      남                                                  57.8
#         여                                                  66.4
# 연령      만10대미만                                             46.6
#         만10-19세                                            63.5
# ...                                                         ...
# 가구주와의관계 부모(배우자부모포함)                                        50.1
#         조부모(배우자조부모포함)                                         -
#         형제자매/그배우자                                          72.1
#         기타친인척                                              79.8
#         동거인                                                77.9
#
# 구분별(1)                                                                   2018  \
# 구분별(1)                방송/동영상(OTT 서비스 등) (%) 포털애플리케이션(네이버 다음 네이트 등) (%) 게임 (%)
# 전체      소계                             12.5                       45.4   21.3
# 성별      남                              12.9                       45.0   27.7
#         여                              12.1                       45.8   14.7
# 연령      만10대미만                         39.8                       12.3   59.4
#         만10-19세                        24.4                       31.7   49.3
# ...                                     ...                        ...    ...
# 가구주와의관계 부모(배우자부모포함)                     4.1                       21.1   14.2
#         조부모(배우자조부모포함)                     -                          -      -
#         형제자매/그배우자                       9.9                       49.7   20.4
#         기타친인척                          15.5                       64.2   57.8
#         동거인                            25.8                       41.1    7.1
#
# 구분별(1)                                               \
# 구분별(1)                소셜네트워킹(카카오스토리 페이스북 트위터 등) (%)
# 전체      소계                                     18.4
# 성별      남                                      15.8
#         여                                      21.1
# 연령      만10대미만                                  5.1
#         만10-19세                                24.1
# ...                                             ...
# 가구주와의관계 부모(배우자부모포함)                             4.0
#         조부모(배우자조부모포함)                             -
#         형제자매/그배우자                              21.2
#         기타친인척                                  32.7
#         동거인                                    28.1
#
# 구분별(1)                                                           \
# 구분별(1)                인스턴트메신저(카카오톡 라인 페이스북 등의 SNS 자체 메신저 등) (%)
# 전체      소계                                                 61.6
# 성별      남                                                  55.6
#         여                                                  67.9
# 연령      만10대미만                                             35.4
#         만10-19세                                            60.0
# ...                                                         ...
# 가구주와의관계 부모(배우자부모포함)                                        36.2
#         조부모(배우자조부모포함)                                         -
#         형제자매/그배우자                                          38.0
#         기타친인척                                              79.2
#         동거인                                                63.1
#
# 구분별(1)                                                                  ...  \
# 구분별(1)                방송/동영상(OTT 서비스 등) (%) 포털애플리케이션(네이버 다음 네이트 등) (%)  ...
# 전체      소계                             17.1                       44.4  ...
# 성별      남                              18.7                       45.3  ...
#         여                              15.3                       43.4  ...
# 연령      만10대미만                         53.3                       20.7  ...
#         만10-19세                        35.7                       28.5  ...
# ...                                     ...                        ...  ...
# 가구주와의관계 부모(배우자부모포함)                    12.7                       18.4  ...
#         조부모(배우자조부모포함)                     -                          -  ...
#         형제자매/그배우자                       8.1                       45.2  ...
#         기타친인척                          15.6                        9.5  ...
#         동거인                            36.9                        0.0  ...
#
# 구분별(1)                  2020                                \
# 구분별(1)                게임 (%) 소셜네트워킹(카카오스토리 페이스북 트위터 등) (%)
# 전체      소계              20.4                          13.9
# 성별      남               28.6                          12.2
#         여               11.8                          15.6
# 연령      만10대미만          68.2                           0.3
#         만10-19세         55.1                          14.9
# ...                      ...                           ...
# 가구주와의관계 부모(배우자부모포함)     13.6                           6.6
#         조부모(배우자조부모포함)    0.0                           0.0
#         형제자매/그배우자       12.0                          29.9
#         기타친인척           49.6                          18.8
#         동거인              0.0                           0.0
#
# 구분별(1)                                                           \
# 구분별(1)                인스턴트메신저(카카오톡 라인 페이스북 등의 SNS 자체 메신저 등) (%)
# 전체      소계                                                 69.4
# 성별      남                                                  64.9
#         여                                                  74.1
# 연령      만10대미만                                             39.9
#         만10-19세                                            58.3
# ...                                                         ...
# 가구주와의관계 부모(배우자부모포함)                                        86.9
#         조부모(배우자조부모포함)                                     100.0
#         형제자매/그배우자                                          82.8
#         기타친인척                                             100.0
#         동거인                                               100.0
#
# 구분별(1)                                                                   2021  \
# 구분별(1)                방송/동영상(OTT 서비스 등) (%) 포털애플리케이션(네이버 다음 네이트 등) (%) 게임 (%)
# 전체      소계                             26.1                       47.8   20.4
# 성별      남                              29.1                       48.5   29.0
#         여                              22.9                       47.1   11.4
# 연령      만10대미만                         42.3                       14.8   66.9
#         만10-19세                        37.1                       26.3   58.5
# ...                                     ...                        ...    ...
# 가구주와의관계 부모(배우자부모포함)                     2.9                       39.5    9.9
#         조부모(배우자조부모포함)                   0.0                        0.0      -
#         형제자매/그배우자                      31.2                       58.8   12.7
#         기타친인척                          14.0                       44.1   22.3
#         동거인                             0.0                        0.0    0.0
#
# 구분별(1)                                               \
# 구분별(1)                소셜네트워킹(카카오스토리 페이스북 트위터 등) (%)
# 전체      소계                                     10.3
# 성별      남                                       8.9
#         여                                      11.8
# 연령      만10대미만                                  0.0
#         만10-19세                                13.3
# ...                                             ...
# 가구주와의관계 부모(배우자부모포함)                             5.8
#         조부모(배우자조부모포함)                             -
#         형제자매/그배우자                              42.0
#         기타친인척                                   0.0
#         동거인                                    79.9
#
# 구분별(1)                                                           \
# 구분별(1)                인스턴트메신저(카카오톡 라인 페이스북 등의 SNS 자체 메신저 등) (%)
# 전체      소계                                                 64.0
# 성별      남                                                  58.4
#         여                                                  69.8
# 연령      만10대미만                                             32.1
#         만10-19세                                            53.9
# ...                                                         ...
# 가구주와의관계 부모(배우자부모포함)                                        60.7
#         조부모(배우자조부모포함)                                         -
#         형제자매/그배우자                                          58.1
#         기타친인척                                              95.3
#         동거인                                                20.1
#
# 구분별(1)
# 구분별(1)                방송/동영상(OTT 서비스 등) (%) 포털애플리케이션(네이버 다음 네이트 등) (%)
# 전체      소계                             34.0                       45.4
# 성별      남                              36.4                       47.3
#         여                              31.5                       43.4
# 연령      만10대미만                         35.8                       20.7
#         만10-19세                        42.8                       20.4
# ...                                     ...                        ...
# 가구주와의관계 부모(배우자부모포함)                     5.1                       30.3
#         조부모(배우자조부모포함)                     -                          -
#         형제자매/그배우자                      32.1                       43.3
#         기타친인척                          39.3                       24.2
#         동거인                             0.0                       20.1
#
# [86 rows x 25 columns]

# %%
data = {"2017" : application["2017"]["방송/동영상(OTT 서비스 등) (%)"], "2018": application["2018"]["방송/동영상(OTT 서비스 등) (%)"],"2019": application["2019"]["방송/동영상(OTT 서비스 등) (%)"],"2020": application["2020"]["방송/동영상(OTT 서비스 등) (%)"],"2021": application["2021"]["방송/동영상(OTT 서비스 등) (%)"]}
OTT_application = pd.DataFrame(data=data)

# %%
OTT_application_age = OTT_application.loc["연령"]

# %%
OTT_application_age
# Out:
#          2017  2018  2019  2020  2021
# 만10대미만   39.8  53.3  54.7  42.3  35.8
# 만10-19세  24.4  35.7  32.2  37.1  42.8
# 만20-29세  15.8  22.1  20.3  39.5  45.5
# 만30-39세  10.5  16.4  14.4  27.1  33.6
# 만40-49세  10.2  10.4  13.1  19.9  30.7
# 만50-59세   9.9  13.8  12.4  22.3  30.8
# 만60-69세   6.9   9.1  10.5  16.7  29.1
# 만70세이상    2.9   6.1  15.5  11.0  20.6

# %%
OTT_application_age["2017"].mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\nanops.py:1622, in _ensure_numeric(x)
#    1621 try:
# -> 1622     x = float(x)
#    1623 except (TypeError, ValueError):
#    1624     # e.g. "1+1j" or "foo"
#
# ValueError: could not convert string to float: '39.824.415.810.510.29.96.92.9'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\nanops.py:1626, in _ensure_numeric(x)
#    1625 try:
# -> 1626     x = complex(x)
#    1627 except ValueError as err:
#    1628     # e.g. "foo"
#
# ValueError: complex() arg is a malformed string
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Input In [59], in <cell line: 1>()
# ----> 1 OTT_application_age["2017"].mean()
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:11117, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11099 @doc(
#   11100     _num_doc,
#   11101     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11115     **kwargs,
#   11116 ):
# > 11117     return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:10687, in NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10679 def mean(
#   10680     self,
#   10681     axis: Axis | None | lib.NoDefault = lib.no_default,
#    (...)
#   10685     **kwargs,
#   10686 ) -> Series | float:
# > 10687     return self._stat_function(
#   10688         "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
#   10689     )
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:10639, in NDFrame._stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   10629     warnings.warn(
#   10630         "Using the level keyword in DataFrame and Series aggregations is "
#   10631         "deprecated and will be removed in a future version. Use groupby "
#    (...)
#   10634         stacklevel=find_stack_level(),
#   10635     )
#   10636     return self._agg_by_level(
#   10637         name, axis=axis, level=level, skipna=skipna, numeric_only=numeric_only
#   10638     )
# > 10639 return self._reduce(
#   10640     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   10641 )
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:4471, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4467     raise NotImplementedError(
#    4468         f"Series.{name} does not implement {kwd_name}."
#    4469     )
#    4470 with np.errstate(all="ignore"):
# -> 4471     return op(delegate, skipna=skipna, **kwds)
#
# File ~\anaconda3\lib\site-packages\pandas\core\nanops.py:93, in disallow.__call__.<locals>._f(*args, **kwargs)
#      91 try:
#      92     with np.errstate(invalid="ignore"):
# ---> 93         return f(*args, **kwargs)
#      94 except ValueError as e:
#      95     # we want to transform an object array
#      96     # ValueError message to the more typical TypeError
#      97     # e.g. this is normally a disallowed function on
#      98     # object arrays that contain strings
#      99     if is_object_dtype(args[0]):
#
# File ~\anaconda3\lib\site-packages\pandas\core\nanops.py:155, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     153         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     154 else:
# --> 155     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157 return result
#
# File ~\anaconda3\lib\site-packages\pandas\core\nanops.py:410, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     407 if datetimelike and mask is None:
#     408     mask = isna(values)
# --> 410 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     412 if datetimelike:
#     413     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File ~\anaconda3\lib\site-packages\pandas\core\nanops.py:698, in nanmean(values, axis, skipna, mask)
#     695     dtype_count = dtype
#     697 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 698 the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     700 if axis is not None and getattr(the_sum, "ndim", False):
#     701     count = cast(np.ndarray, count)
#
# File ~\anaconda3\lib\site-packages\pandas\core\nanops.py:1629, in _ensure_numeric(x)
#    1626             x = complex(x)
#    1627         except ValueError as err:
#    1628             # e.g. "foo"
# -> 1629             raise TypeError(f"Could not convert {x} to numeric") from err
#    1630 return x
#
# TypeError: Could not convert 39.824.415.810.510.29.96.92.9 to numeric

# %%
OTT_application_age = OTT_application_age.astype(float)

# %%
OTT_application_age.mean()
# Out:
# 2017    15.0500
# 2018    20.8625
# 2019    21.6375
# 2020    26.9875
# 2021    33.6125
# dtype: float64

# %%
OTT_application_age.loc["mean"]=OTT_application_age.mean()

# %%
OTT_application_age.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9 entries, 만10대미만 to mean
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2017    9 non-null      float64
#  1   2018    9 non-null      float64
#  2   2019    9 non-null      float64
#  3   2020    9 non-null      float64
#  4   2021    9 non-null      float64
# dtypes: float64(5)
# memory usage: 732.0+ bytes

# %%
plt.plot(OTT_application_age.loc["mean"])
# 다운로드 받은 앱 중 OTT관련 앱을 자주 사용하는 사람들의 비율의 평균은 계속 증가하고 있다.

# %% [markdown]
# ## OTT서비스 이용 콘텐츠
#
# - TV와 영화 비교

# %%
TV = pd.read_csv("TV방송프로그램.csv", header=[0,1], index_col=[0,1])

# %%
TV
# Out:
# 구분별(1)                 2016                            \
# 구분별(1)              사례수 (명) 티빙(Tving) (%) 푹(Pooq) (%)
# 전체      소계            522.0          22.0        11.4
# 성별      남             270.6          25.3        13.2
#         여             251.4          18.2         9.4
# 연령      만10대미만          4.6          86.6         0.0
#         만10-19세        57.9           9.6         7.7
# ...                     ...           ...         ...
# 가구주와의관계 손자.녀/그배우자      17.5          37.7        16.2
#         부모(배우자부모포함)       -             -           -
#         형제자매/그배우자       4.6          89.2        10.8
#         기타친인척             -             -           -
#         동거인               -             -           -
#
# 구분별(1)                                                            \
# 구분별(1)              oksusu(구 호핀 SK Btv 모바일) (%) olleh TV 모바일 (%)
# 전체      소계                                 23.0              9.4
# 성별      남                                  23.0             14.8
#         여                                  23.0              3.1
# 연령      만10대미만                             56.0              0.0
#         만10-19세                            15.2              9.9
# ...                                         ...              ...
# 가구주와의관계 손자.녀/그배우자                          37.4              0.0
#         부모(배우자부모포함)                           -                -
#         형제자매/그배우자                           0.0             89.2
#         기타친인척                                 -                -
#         동거인                                   -                -
#
# 구분별(1)                                                                       \
# 구분별(1)              U+모바일TV(LTE 비디오포털(구 LG U+ HDTV LG U+ HDTV)) (%) 유튜브 (%)
# 전체      소계                                                      6.2    25.9
# 성별      남                                                       5.1    19.2
#         여                                                       7.6    33.7
# 연령      만10대미만                                                  0.0     0.0
#         만10-19세                                                 5.1    49.9
# ...                                                             ...     ...
# 가구주와의관계 손자.녀/그배우자                                               0.0    25.2
#         부모(배우자부모포함)                                               -       -
#         형제자매/그배우자                                               0.0     0.0
#         기타친인척                                                     -       -
#         동거인                                                       -       -
#
# 구분별(1)                                                        ...  \
# 구분별(1)              넷플릭스(Netflix) (%) 에브리온 TV (%) 카카오 TV (%)  ...
# 전체      소계                        0.8         0.3        6.3  ...
# 성별      남                         0.0         0.4        7.3  ...
#         여                         1.8         0.2        5.2  ...
# 연령      만10대미만                    0.0         0.0       47.3  ...
#         만10-19세                   0.0         0.0        3.9  ...
# ...                               ...         ...        ...  ...
# 가구주와의관계 손자.녀/그배우자                 0.0         0.0       15.9  ...
#         부모(배우자부모포함)                 -           -          -  ...
#         형제자매/그배우자                 0.0         0.0        0.0  ...
#         기타친인척                       -           -          -  ...
#         동거인                         -           -          -  ...
#
# 구분별(1)                          2019  \
# 구분별(1)              olleh TV 모바일 (%)
# 전체      소계                       6.4
# 성별      남                        4.0
#         여                        9.2
# 연령      만10대미만                   5.4
#         만10-19세                  4.7
# ...                              ...
# 가구주와의관계 손자.녀/그배우자                0.0
#         부모(배우자부모포함)              0.0
#         형제자매/그배우자               22.6
#         기타친인척                  100.0
#         동거인                      0.0
#
# 구분별(1)                                                                       \
# 구분별(1)              U+모바일TV(LTE 비디오포털(구 LG U+ HDTV LG U+ HDTV)) (%) 유튜브 (%)
# 전체      소계                                                      6.6    64.1
# 성별      남                                                       6.8    67.6
#         여                                                       6.2    60.0
# 연령      만10대미만                                                  8.1    84.4
#         만10-19세                                                 3.0    72.4
# ...                                                             ...     ...
# 가구주와의관계 손자.녀/그배우자                                               0.0    83.7
#         부모(배우자부모포함)                                             0.0     0.0
#         형제자매/그배우자                                               0.0    40.9
#         기타친인척                                                   0.0     0.0
#         동거인                                                     0.0    37.9
#
# 구분별(1)                                                                 \
# 구분별(1)              넷플릭스(Netflix) (%) 에브리온 TV (%) 카카오 TV (%) 곰 TV (%)
# 전체      소계                       14.5         0.2       19.0      5.3
# 성별      남                        14.5         0.1       18.7      6.9
#         여                        14.5         0.2       19.3      3.5
# 연령      만10대미만                    0.0         0.0       14.5     16.5
#         만10-19세                  14.6         0.0       24.0      7.5
# ...                               ...         ...        ...      ...
# 가구주와의관계 손자.녀/그배우자                 7.2         0.0        7.2      0.0
#         부모(배우자부모포함)               0.0         0.0        0.0      0.0
#         형제자매/그배우자                 0.0         0.0       36.7      0.0
#         기타친인척                     0.0         0.0        0.0      0.0
#         동거인                       0.0         0.0        0.0      0.0
#
# 구분별(1)
# 구분별(1)              네이버 시리즈(구 네이버N 스토어) (%) 아마존 프라임 비디오 (%) 기타 (%)
# 전체      소계                              4.0             0.7    0.7
# 성별      남                               3.0             1.2    0.2
#         여                               5.2             0.2    1.3
# 연령      만10대미만                          0.0             0.0    0.0
#         만10-19세                         1.8             0.1    0.1
# ...                                     ...             ...    ...
# 가구주와의관계 손자.녀/그배우자                       0.0             0.0    3.9
#         부모(배우자부모포함)                     0.0             0.0    0.0
#         형제자매/그배우자                       0.0             0.0    0.0
#         기타친인척                           0.0             0.0    0.0
#         동거인                             0.0             0.0    0.0
#
# [85 rows x 51 columns]

# %% [markdown]
# ## OTT서비스 주 이용 콘텐츠

# %%
OTT_genre = pd.read_excel("가장많이이용하는OTT서비스_20-21.xlsx", header=[0,1], index_col=[0,1])
# Out:
# C:\Users\gyeoa\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
OTT_genre
# Out:
# 구분별(2)        2020                                                         \
# 구분별(2)     사례수 (명) TV 방송 프로그램 (VOD/다시보기) (%) 해외 TV 방송 프로그램 (%) 실시간 TV (%)
# 전체 소계       7434.0                      57.0               5.3       24.5
# 성별 남        3872.0                      54.9               5.5       24.9
#    여        3562.0                      59.2               4.9       24.0
# 연령 만10대미만    173.0                      24.9               0.0       12.3
#    만10-19세   825.0                      48.6               2.6       18.3
#    만20-29세  1378.0                      62.6               8.7       27.1
#    만30-39세  1420.0                      57.8               7.5       32.1
#    만40-49세  1481.0                      64.9               5.4       25.2
#    만50-59세  1373.0                      55.3               3.3       21.4
#    만60-69세   666.0                      49.9               2.1       19.2
#    만70세이상    119.0                      46.9               3.0       19.5
#
# 구분별(2)                                                                        \
# 구분별(2)     영화 (%) OTT 사업자 자체 제작 프로그램(넷플릭스 오리지널 등) (%) 예능/오락(개인방송 콘텐츠 포함) (%)
# 전체 소계        22.3                                19.8                   73.1
# 성별 남         23.9                                20.4                   75.2
#    여         20.6                                19.1                   70.8
# 연령 만10대미만     3.2                                 9.7                   85.7
#    만10-19세   15.9                                12.9                   79.6
#    만20-29세   34.8                                23.9                   73.7
#    만30-39세   30.6                                28.2                   69.6
#    만40-49세   23.6                                19.4                   69.2
#    만50-59세   14.8                                16.8                   73.9
#    만60-69세    7.9                                12.9                   74.4
#    만70세이상     3.5                                10.3                   76.0
#
# 구분별(2)                      2021                                        \
# 구분별(2)     음악 (%) 기타 (%) 사례수 (명) 영화 (%) 예능/오락(개인방송 콘텐츠 포함) (%) 드라마 (%)
# 전체 소계        32.1    0.3  8293.7   38.5                   80.5    47.0
# 성별 남         30.3    0.4  4283.5   37.4                   78.6    33.2
#    여         34.1    0.3  4010.2   39.8                   82.5    61.7
# 연령 만10대미만    19.8    1.0   174.5    8.1                   71.3     7.1
#    만10-19세   40.4    0.9   880.1   30.7                   88.8    31.1
#    만20-29세   34.1    0.3  1381.4   61.5                   88.7    57.0
#    만30-39세   30.8    0.1  1390.1   46.9                   86.4    53.2
#    만40-49세   32.0    0.4  1585.9   45.1                   79.8    52.7
#    만50-59세   30.0    0.3  1580.6   29.8                   75.2    45.8
#    만60-69세   31.5    0.2  1025.7   18.1                   69.6    42.7
#    만70세이상    15.2    0.0   275.5   13.5                   64.2    31.5
#
# 구분별(2)
# 구분별(2)     교양/다큐멘터리 (%) 교육/학습 (%) 애니메이션(만화) (%) 스포츠 (%) 뉴스 (%) 기타 (%)
# 전체 소계              19.6       9.2          10.2    23.4   25.8    2.0
# 성별 남               20.6       8.4           9.3    39.9   29.7    1.7
#    여               18.6      10.1          11.2     5.8   21.6    2.2
# 연령 만10대미만           9.3      41.8          72.9     0.3    0.9    0.0
#    만10-19세         12.4      36.1          39.1     9.9    5.1    1.6
#    만20-29세         19.9       8.9          10.5    22.7   11.3    0.9
#    만30-39세         19.1       5.9           8.6    29.9   21.1    1.8
#    만40-49세         18.6       4.7           4.6    26.8   29.5    1.7
#    만50-59세         21.4       4.3           1.5    28.3   36.1    2.6
#    만60-69세         25.4       1.9           1.0    20.7   45.5    2.9
#    만70세이상          25.6       3.2           1.4    15.3   48.9    4.3

# %%
OTT_genre.loc["전체","2020"].T.sort_values(by="소계", ascending=False)
# 예능/오락, TV방송 프로그램이 가장 많은 부분을 차지한다.
# Out:
#                                          소계
# 구분별(2)
# 사례수 (명)                              7434.0
# 예능/오락(개인방송 콘텐츠 포함) (%)                 73.1
# TV 방송 프로그램 (VOD/다시보기) (%)              57.0
# 음악 (%)                                 32.1
# 실시간 TV (%)                             24.5
# 영화 (%)                                 22.3
# OTT 사업자 자체 제작 프로그램(넷플릭스 오리지널 등) (%)    19.8
# 해외 TV 방송 프로그램 (%)                       5.3
# 기타 (%)                                  0.3

# %%
OTT_genre.loc["전체","2021"].T.sort_values(by="소계", ascending=False)
# 예능/오락, 드라마, 영화가 가장 많은 부분을 차지한다.
# Out:
#                             소계
# 구분별(2)
# 사례수 (명)                 8293.7
# 예능/오락(개인방송 콘텐츠 포함) (%)    80.5
# 드라마 (%)                   47.0
# 영화 (%)                    38.5
# 뉴스 (%)                    25.8
# 스포츠 (%)                   23.4
# 교양/다큐멘터리 (%)              19.6
# 애니메이션(만화) (%)             10.2
# 교육/학습 (%)                  9.2
# 기타 (%)                     2.0

# %% [markdown]
# ### 해외 OTT 주요 소비 콘텐츠

# %%
OTTgenreab = pd.read_csv("OTT서비스이용시즐겨보는장르_해외.csv", encoding = "euc-kr", index_col=[0,1,2,3,4])
OTTgenreab
# Out:
#                         사례수(명)  드라마(비율)  버라이어티쇼(비율)  음악(비율)  뉴스시사보도(비율)  \
# 연번  조사연도 국가  분류  구분
# 1   2019 인도  국가별 전체        322      9.6         2.5     9.3         9.9
# 2   2019 터키  국가별 전체        321      4.4         3.1     2.8         7.8
# 3   2019 캐나다 국가별 전체        281     15.3         2.5     3.6         6.8
# 4   2019 헝가리 국가별 전체        223      5.4         0.9     9.0         2.2
# 5   2019 인도  성별  남성        159      7.5         3.1    10.7        10.1
# ...                        ...      ...         ...     ...         ...
# 194 2020 러시아 소득별 평균 이상     122     18.0         5.7     1.6         9.8
# 195 2020 브라질 소득별 평균 이하     178      2.8         1.1     7.3         6.2
# 196 2020 브라질 소득별 평균 이상      87      4.6         0.0     3.4         5.7
# 197 2020 UAE 소득별 평균 이하     165     10.3         4.2     4.2         6.1
# 198 2020 UAE 소득별 평균 이상     122     10.7         1.6     4.1         7.4
#
#                         교육(비율)  영화(비율)  스포츠(비율)  다큐멘터리(비율)  애니메이션(비율)  \
# 연번  조사연도 국가  분류  구분
# 1   2019 인도  국가별 전체        3.4    27.3     12.4        0.9        1.6
# 2   2019 터키  국가별 전체        1.6    37.4      7.5        7.8        2.8
# 3   2019 캐나다 국가별 전체        0.7    23.5      7.5        5.7        2.8
# 4   2019 헝가리 국가별 전체        2.7    36.8      7.6        7.2        2.7
# 5   2019 인도  성별  남성        3.8    26.4     17.0        0.6        1.3
# ...                        ...     ...      ...        ...        ...
# 194 2020 러시아 소득별 평균 이상     2.5    20.5     10.7        3.3        0.0
# 195 2020 브라질 소득별 평균 이하     3.4    36.5     11.8        6.2        3.9
# 196 2020 브라질 소득별 평균 이상     0.0    47.1     16.1        8.0        1.1
# 197 2020 UAE 소득별 평균 이하     3.6    25.5      9.7        7.9        4.2
# 198 2020 UAE 소득별 평균 이상     2.5    29.5      9.8        2.5        1.6
#
#                         코미디(비율)  문화예술(비율)  퀴즈쇼게임쇼(비율)  토크쇼(비율)  키즈(비율)  \
# 연번  조사연도 국가  분류  구분
# 1   2019 인도  국가별 전체        10.6       0.0         0.0      2.2     1.2
# 2   2019 터키  국가별 전체         9.0       0.0         2.5      1.2     5.9
# 3   2019 캐나다 국가별 전체        19.2       0.0         0.0      2.8     3.2
# 4   2019 헝가리 국가별 전체        14.3       0.0         0.0      1.8     0.9
# 5   2019 인도  성별  남성        10.1       0.0         0.0      2.5     1.9
# ...                         ...       ...         ...      ...     ...
# 194 2020 러시아 소득별 평균 이상     12.3       3.3         0.8      4.1     3.3
# 195 2020 브라질 소득별 평균 이하      6.7       1.7         1.7      1.1     2.8
# 196 2020 브라질 소득별 평균 이상      3.4       0.0         1.1      1.1     3.4
# 197 2020 UAE 소득별 평균 이하     10.3       0.6         1.8      4.8     4.2
# 198 2020 UAE 소득별 평균 이상     11.5       1.6         0.8      3.3     2.5
#
#                         리얼리티쇼(비율)  종교(비율)  생활(비율)  시리즈물(비율)  기타(비율)
# 연번  조사연도 국가  분류  구분
# 1   2019 인도  국가별 전체           8.4     0.3     0.0       0.0     0.3
# 2   2019 터키  국가별 전체           4.0     0.6     0.0       0.9     0.6
# 3   2019 캐나다 국가별 전체           5.0     0.7     0.0       0.4     0.4
# 4   2019 헝가리 국가별 전체           4.0     0.0     0.0       3.1     1.3
# 5   2019 인도  성별  남성           4.4     0.0     0.0       0.0     0.6
# ...                           ...     ...     ...       ...     ...
# 194 2020 러시아 소득별 평균 이상        3.3     0.0     0.8       0.0     0.0
# 195 2020 브라질 소득별 평균 이하        1.7     2.2     0.0       0.0     0.0
# 196 2020 브라질 소득별 평균 이상        2.3     0.0     0.0       0.0     0.0
# 197 2020 UAE 소득별 평균 이하        1.2     1.2     0.0       0.0     0.0
# 198 2020 UAE 소득별 평균 이상        8.2     2.5     0.0       0.0     0.0
#
# [198 rows x 20 columns]

# %%
OTTgenre1 = OTTgenreab.droplevel(["연번"])
OTTgenre1
# Out:
#                     사례수(명)  드라마(비율)  버라이어티쇼(비율)  음악(비율)  뉴스시사보도(비율)  교육(비율)  \
# 조사연도 국가  분류  구분
# 2019 인도  국가별 전체        322      9.6         2.5     9.3         9.9     3.4
#      터키  국가별 전체        321      4.4         3.1     2.8         7.8     1.6
#      캐나다 국가별 전체        281     15.3         2.5     3.6         6.8     0.7
#      헝가리 국가별 전체        223      5.4         0.9     9.0         2.2     2.7
#      인도  성별  남성        159      7.5         3.1    10.7        10.1     3.8
# ...                    ...      ...         ...     ...         ...     ...
# 2020 러시아 소득별 평균 이상     122     18.0         5.7     1.6         9.8     2.5
#      브라질 소득별 평균 이하     178      2.8         1.1     7.3         6.2     3.4
#              평균 이상      87      4.6         0.0     3.4         5.7     0.0
#      UAE 소득별 평균 이하     165     10.3         4.2     4.2         6.1     3.6
#              평균 이상     122     10.7         1.6     4.1         7.4     2.5
#
#                     영화(비율)  스포츠(비율)  다큐멘터리(비율)  애니메이션(비율)  코미디(비율)  문화예술(비율)  \
# 조사연도 국가  분류  구분
# 2019 인도  국가별 전체       27.3     12.4        0.9        1.6     10.6       0.0
#      터키  국가별 전체       37.4      7.5        7.8        2.8      9.0       0.0
#      캐나다 국가별 전체       23.5      7.5        5.7        2.8     19.2       0.0
#      헝가리 국가별 전체       36.8      7.6        7.2        2.7     14.3       0.0
#      인도  성별  남성       26.4     17.0        0.6        1.3     10.1       0.0
# ...                    ...      ...        ...        ...      ...       ...
# 2020 러시아 소득별 평균 이상    20.5     10.7        3.3        0.0     12.3       3.3
#      브라질 소득별 평균 이하    36.5     11.8        6.2        3.9      6.7       1.7
#              평균 이상    47.1     16.1        8.0        1.1      3.4       0.0
#      UAE 소득별 평균 이하    25.5      9.7        7.9        4.2     10.3       0.6
#              평균 이상    29.5      9.8        2.5        1.6     11.5       1.6
#
#                     퀴즈쇼게임쇼(비율)  토크쇼(비율)  키즈(비율)  리얼리티쇼(비율)  종교(비율)  생활(비율)  \
# 조사연도 국가  분류  구분
# 2019 인도  국가별 전체            0.0      2.2     1.2        8.4     0.3     0.0
#      터키  국가별 전체            2.5      1.2     5.9        4.0     0.6     0.0
#      캐나다 국가별 전체            0.0      2.8     3.2        5.0     0.7     0.0
#      헝가리 국가별 전체            0.0      1.8     0.9        4.0     0.0     0.0
#      인도  성별  남성            0.0      2.5     1.9        4.4     0.0     0.0
# ...                        ...      ...     ...        ...     ...     ...
# 2020 러시아 소득별 평균 이상         0.8      4.1     3.3        3.3     0.0     0.8
#      브라질 소득별 평균 이하         1.7      1.1     2.8        1.7     2.2     0.0
#              평균 이상         1.1      1.1     3.4        2.3     0.0     0.0
#      UAE 소득별 평균 이하         1.8      4.8     4.2        1.2     1.2     0.0
#              평균 이상         0.8      3.3     2.5        8.2     2.5     0.0
#
#                     시리즈물(비율)  기타(비율)
# 조사연도 국가  분류  구분
# 2019 인도  국가별 전체          0.0     0.3
#      터키  국가별 전체          0.9     0.6
#      캐나다 국가별 전체          0.4     0.4
#      헝가리 국가별 전체          3.1     1.3
#      인도  성별  남성          0.0     0.6
# ...                      ...     ...
# 2020 러시아 소득별 평균 이상       0.0     0.0
#      브라질 소득별 평균 이하       0.0     0.0
#              평균 이상       0.0     0.0
#      UAE 소득별 평균 이하       0.0     0.0
#              평균 이상       0.0     0.0
#
# [198 rows x 20 columns]

# %%
nineabgenrenine = OTTgenre1.iloc[0:4].droplevel(["조사연도","분류", "구분"]).T
nineabgenrenine
# Out:
# 국가             인도     터키    캐나다    헝가리
# 사례수(명)      322.0  321.0  281.0  223.0
# 드라마(비율)       9.6    4.4   15.3    5.4
# 버라이어티쇼(비율)    2.5    3.1    2.5    0.9
# 음악(비율)        9.3    2.8    3.6    9.0
# 뉴스시사보도(비율)    9.9    7.8    6.8    2.2
# 교육(비율)        3.4    1.6    0.7    2.7
# 영화(비율)       27.3   37.4   23.5   36.8
# 스포츠(비율)      12.4    7.5    7.5    7.6
# 다큐멘터리(비율)     0.9    7.8    5.7    7.2
# 애니메이션(비율)     1.6    2.8    2.8    2.7
# 코미디(비율)      10.6    9.0   19.2   14.3
# 문화예술(비율)      0.0    0.0    0.0    0.0
# 퀴즈쇼게임쇼(비율)    0.0    2.5    0.0    0.0
# 토크쇼(비율)       2.2    1.2    2.8    1.8
# 키즈(비율)        1.2    5.9    3.2    0.9
# 리얼리티쇼(비율)     8.4    4.0    5.0    4.0
# 종교(비율)        0.3    0.6    0.7    0.0
# 생활(비율)        0.0    0.0    0.0    0.0
# 시리즈물(비율)      0.0    0.9    0.4    3.1
# 기타(비율)        0.3    0.6    0.4    1.3

# %%
nineamerica = OTTgenre1.iloc[72:74].droplevel(["조사연도","분류"]).T
nineamerica
manamerica = nineamerica["미국"].sort_values(by=["남성"], ascending=False).head()
womanamerica = nineamerica["미국"].sort_values(by=["여성"], ascending=False).head()

# %%
India = abgenrenine.sort_values(by="인도", ascending=False).head()["인도"]
Turkey = abgenrenine.sort_values(by="터키", ascending=False).head()["터키"]
Canada = abgenrenine.sort_values(by="캐나다", ascending=False).head()["캐나다"]
Hungary = abgenrenine.sort_values(by="헝가리", ascending=False).head()["헝가리"]
print(India,"\n", Turkey, "\n", Canada, "\n", Hungary)
# Out:
# 사례수(명)        322.0
# 영화(비율)         27.3
# 스포츠(비율)        12.4
# 코미디(비율)        10.6
# 뉴스시사보도(비율)      9.9
# Name: 인도, dtype: float64
#  사례수(명)        321.0
# 영화(비율)         37.4
# 코미디(비율)         9.0
# 다큐멘터리(비율)       7.8
# 뉴스시사보도(비율)      7.8
# Name: 터키, dtype: float64
#  사례수(명)     281.0
# 영화(비율)      23.5
# 코미디(비율)     19.2
# 드라마(비율)     15.3
# 스포츠(비율)      7.5
# Name: 캐나다, dtype: float64
#  사례수(명)     223.0
# 영화(비율)      36.8
# 코미디(비율)     14.3
# 음악(비율)       9.0
# 스포츠(비율)      7.6
# Name: 헝가리, dtype: float64

# %%
tengenreab = OTTgenre1.iloc[103:108].droplevel(["조사연도","분류","구분"]).T

# %%
England = tengenreab.sort_values(by="영국", ascending=False).head()["영국"]
Austrailia = tengenreab.sort_values(by="호주", ascending=False).head()["호주"]
Russia = tengenreab.sort_values(by="러시아", ascending=False).head()["러시아"]
Brazil = tengenreab.sort_values(by="브라질", ascending=False).head()["브라질"]
UAE = tengenreab.sort_values(by="UAE", ascending=False).head()["UAE"]
lst2 = [England, Austrailia, Russia, Brazil, UAE]

# %%
lst = [manamerica, womanamerica, India, Turkey, Canada, Hungary]
ninetopfive = pd.concat(lst, axis=1)
tentopfive = pd.concat(lst2, axis=1)

total = pd.concat([ninetopfive, tentopfive], axis=1)

# %%
total
#### 영국과 미국여성을 제외하고 영화(비율)이 가장 높음(주로 보려는 장르가)
# Out:
#                남성     여성     남성     여성     인도     터키    캐나다    헝가리     영국  \
# 사례수(명)      163.0  168.0  163.0  168.0  322.0  321.0  281.0  223.0  373.0
# 영화(비율)       32.5   29.2   32.5   29.2   27.3   37.4   23.5   36.8    NaN
# 뉴스시사보도(비율)   20.2    6.0    NaN    NaN    9.9    7.8    NaN    NaN    NaN
# 애니메이션(비율)    14.1    6.5   14.1    6.5    NaN    NaN    NaN    NaN    NaN
# 스포츠(비율)      13.5    4.2    NaN    NaN   12.4    NaN    7.5    7.6    NaN
# 드라마(비율)       NaN    NaN   12.3   33.3    NaN    NaN   15.3    NaN   14.5
# 버라이어티쇼(비율)    NaN    NaN    3.7   14.9    NaN    NaN    NaN    NaN   18.2
# 코미디(비율)       NaN    NaN    NaN    NaN   10.6    9.0   19.2   14.3    NaN
# 다큐멘터리(비율)     NaN    NaN    NaN    NaN    NaN    7.8    NaN    NaN    NaN
# 음악(비율)        NaN    NaN    NaN    NaN    NaN    NaN    NaN    9.0    5.6
# 교육(비율)        NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    5.6
#
#                호주    러시아    브라질    UAE
# 사례수(명)      301.0  367.0  368.0  355.0
# 영화(비율)       16.9   23.4   39.9   26.8
# 뉴스시사보도(비율)    NaN    NaN    NaN    NaN
# 애니메이션(비율)     NaN    NaN    NaN    NaN
# 스포츠(비율)      10.3    9.3   11.1    9.3
# 드라마(비율)      16.6   20.7    NaN   10.4
# 버라이어티쇼(비율)    NaN    NaN    NaN    NaN
# 코미디(비율)      13.0   10.6    7.3   12.7
# 다큐멘터리(비율)     NaN    NaN    6.5    NaN
# 음악(비율)        NaN    NaN    NaN    NaN
# 교육(비율)        NaN    NaN    NaN    NaN

# %%
# 해외의 경우를 우리나라에 적용할 수는 없지만 참고를 위해 첨부합니다.

# %% [markdown]
# ## OTT 서비스 이용 빈도와 이용 시간
#
# - OTT서비스를 끊어서 보는 사람들의 비율이 많을까?

# %%
frequency = pd.read_csv("OTT서비스_이용빈도.csv", header=[0,1], index_col=[0,1])
frequency
# Out:
# 구분별(1)                 2019                                          \
# 구분별(1)              사례수 (명) 하루에도 여러번 (%) 하루1번(매일) (%) 1주일에 5~6회 (%)
# 전체      소계           4457.7         20.8         13.4           8.5
# 성별      남            2375.6         21.8         12.8           8.8
#         여            2082.1         19.6         14.0           8.1
# 연령      만10대미만         80.6         22.4         18.5          10.3
#         만10-19세       501.5         34.5         12.6          12.3
# ...                     ...          ...          ...           ...
# 가구주와의관계 손자.녀/그배우자      43.0         25.7          9.6           5.4
#         부모(배우자부모포함)    11.1         39.0          5.5           0.0
#         형제자매/그배우자      43.6         27.0         11.6          18.6
#         기타친인척          15.2         44.2          0.0           0.0
#         동거인             4.0          0.0          0.0           0.0
#
# 구분별(1)                                                                \
# 구분별(1)              1주일에 3~4회 (%) 1주일에 1~2회 (%) 월1~3회 (%) 월1회 미만 (%)
# 전체      소계                   13.8          28.9      11.2        2.9
# 성별      남                    14.2          27.8      11.2        2.9
#         여                    13.4          30.2      11.1        3.0
# 연령      만10대미만                5.8          16.0      22.5        4.5
#         만10-19세              11.1          19.9       6.3        2.0
# ...                           ...           ...       ...        ...
# 가구주와의관계 손자.녀/그배우자            12.9          39.8       6.7        0.0
#         부모(배우자부모포함)           0.0           0.0      55.6        0.0
#         형제자매/그배우자             5.4          35.1       2.3        0.0
#         기타친인척                14.8           0.0      41.0        0.0
#         동거인                   0.0         100.0       0.0        0.0
#
# 구분별(1)                             2020  ...                2021               \
# 구분별(1)              분기/연간1회 (%) 사례수 (명)  ... 분기/연간1회 (%) 사례수 (명) 하루에도 여러번 (%)
# 전체      소계                  0.5  7434.0  ...         0.1  8293.7         36.5
# 성별      남                   0.4  3872.0  ...         0.2  4283.5         36.7
#         여                   0.6  3562.0  ...         0.0  4010.2         36.2
# 연령      만10대미만              0.0   173.0  ...         0.0   174.5         33.2
#         만10-19세             1.3   825.0  ...         0.2   880.1         50.0
# ...                         ...     ...  ...         ...     ...          ...
# 가구주와의관계 손자.녀/그배우자           0.0    67.0  ...         0.0    74.7         47.3
#         부모(배우자부모포함)         0.0    20.0  ...         0.0    22.2         35.1
#         형제자매/그배우자           0.0    73.0  ...         0.0    75.8         56.1
#         기타친인척               0.0    10.0  ...         0.0    14.0         34.1
#         동거인                 0.0     2.0  ...         0.0     9.3         20.1
#
# 구분별(1)                                                                      \
# 구분별(1)              하루1번(매일) (%) 1주일에 5~6회 (%) 1주일에 3~4회 (%) 1주일에 1~2회 (%)
# 전체      소계                  15.0           9.2          14.7          17.9
# 성별      남                   15.8           9.3          13.8          18.1
#         여                   14.1           9.2          15.7          17.7
# 연령      만10대미만              21.9           7.2          13.2          19.6
#         만10-19세             14.3          11.0          10.5          11.9
# ...                          ...           ...           ...           ...
# 가구주와의관계 손자.녀/그배우자           11.7          13.5          18.0           7.8
#         부모(배우자부모포함)          5.1           0.0          34.2          13.6
#         형제자매/그배우자            5.4           2.0          21.0          12.1
#         기타친인척                2.0          21.0           4.7           0.0
#         동거인                  0.0           0.0           0.0          79.9
#
# 구분별(1)
# 구분별(1)              월1~3회 (%) 월1회 미만 (%) 분기/연간1회 (%)
# 전체      소계                5.6        1.0         0.0
# 성별      남                 5.0        1.3         0.0
#         여                 6.3        0.6         0.0
# 연령      만10대미만            3.8        1.1         0.0
#         만10-19세           2.0        0.4         0.0
# ...                       ...        ...         ...
# 가구주와의관계 손자.녀/그배우자         1.8        0.0         0.0
#         부모(배우자부모포함)       2.0       10.0         0.0
#         형제자매/그배우자         3.4        0.0         0.0
#         기타친인척            38.2        0.0         0.0
#         동거인               0.0        0.0         0.0
#
# [85 rows x 27 columns]

# %%
"2019" = frequency.loc["전체","2019"].T.sort_values(by="소계", ascending=False)
# Out:
#                    소계
# 구분별(1)
# 사례수 (명)        4457.7
# 1주일에 1~2회 (%)    28.9
# 하루에도 여러번 (%)     20.8
# 1주일에 3~4회 (%)    13.8
# 하루1번(매일) (%)     13.4
# 월1~3회 (%)        11.2
# 1주일에 5~6회 (%)     8.5
# 월1회 미만 (%)        2.9
# 분기/연간1회 (%)       0.5

# %%
frequency.loc["전체","2020"].T.sort_values(by="소계", ascending=False)
# Out:
#                    소계
# 구분별(1)
# 사례수 (명)        7434.0
# 하루에도 여러번 (%)     35.0
# 1주일에 1~2회 (%)    18.0
# 하루1번(매일) (%)     15.4
# 1주일에 3~4회 (%)    14.1
# 1주일에 5~6회 (%)    10.3
# 월1~3회 (%)         5.3
# 월1회 미만 (%)        1.7
# 분기/연간1회 (%)       0.1

# %%
frequency.loc["전체","2021"].T.sort_values(by="소계", ascending=False)
# Out:
#                    소계
# 구분별(1)
# 사례수 (명)        8293.7
# 하루에도 여러번 (%)     36.5
# 1주일에 1~2회 (%)    17.9
# 하루1번(매일) (%)     15.0
# 1주일에 3~4회 (%)    14.7
# 1주일에 5~6회 (%)     9.2
# 월1~3회 (%)         5.6
# 월1회 미만 (%)        1.0
# 분기/연간1회 (%)       0.0

# %%
time = pd.read_csv("OTT서비스_이용시간.csv", header=[0,1], index_col=[0,1])
time
# Out:
# 구분별(1)                 2019                                               \
# 구분별(1)              사례수 (명) 5분 미만 (%) 5분 이상 10분 미만 (%) 10분 이상 30분 미만 (%)
# 전체      소계           4457.7       1.1              7.3              43.3
# 성별      남            2375.6       0.9              7.0              44.0
#         여            2082.1       1.4              7.8              42.5
# 연령      만10대미만         80.6       4.5              3.5              42.5
#         만10-19세       501.5       0.9              4.6              32.8
# ...                     ...       ...              ...               ...
# 가구주와의관계 손자.녀/그배우자      43.0       0.0              4.1              31.4
#         부모(배우자부모포함)    11.1       8.1             35.2              23.2
#         형제자매/그배우자      43.6       0.0             14.3              46.2
#         기타친인척          15.2       0.0             35.8              20.0
#         동거인             4.0       0.0              0.0              17.8
#
# 구분별(1)                                                                2020  \
# 구분별(1)              30분 이상 1시간 미만 (%) 1시간 이상 2시간 미만 (%) 2시간 이상 (%) 사례수 (명)
# 전체      소계                       25.8              14.8        7.6  7434.0
# 성별      남                        24.8              16.4        7.0  3872.0
#         여                        27.0              13.0        8.4  3562.0
# 연령      만10대미만                   31.4              13.4        4.8   173.0
#         만10-19세                  25.6              24.0       12.1   825.0
# ...                               ...               ...        ...     ...
# 가구주와의관계 손자.녀/그배우자                36.1              13.4       15.1    67.0
#         부모(배우자부모포함)               0.0              33.5        0.0    20.0
#         형제자매/그배우자                38.7               0.8        0.0    73.0
#         기타친인척                     0.0               0.0       44.2    10.0
#         동거인                      82.2               0.0        0.0     2.0
#
# 구분별(1)                                                            \
# 구분별(1)              5분 미만 (%) 5분 이상 10분 미만 (%) 10분 이상 30분 미만 (%)
# 전체      소계                0.2              2.0              33.1
# 성별      남                 0.2              2.1              33.1
#         여                 0.1              2.0              33.1
# 연령      만10대미만            0.0              0.2              27.6
#         만10-19세           0.1              1.1              25.5
# ...                       ...              ...               ...
# 가구주와의관계 손자.녀/그배우자         0.0              0.7              29.4
#         부모(배우자부모포함)       0.0             33.3              22.0
#         형제자매/그배우자         0.0              0.0              37.3
#         기타친인척             0.0              3.0              85.7
#         동거인               0.0              0.0               0.0
#
# 구분별(1)
# 구분별(1)              30분 이상 1시간 미만 (%) 1시간 이상 2시간 미만 (%) 2시간 이상 (%)
# 전체      소계                       31.9              21.0       11.9
# 성별      남                        31.7              21.1       11.8
#         여                        32.0              20.8       12.0
# 연령      만10대미만                   26.8              23.9       21.6
#         만10-19세                  30.4              22.4       20.5
# ...                               ...               ...        ...
# 가구주와의관계 손자.녀/그배우자                37.5              22.8        9.6
#         부모(배우자부모포함)               5.2              39.5        0.0
#         형제자매/그배우자                40.7              10.8       11.2
#         기타친인척                     0.0              11.3        0.0
#         동거인                     100.0               0.0        0.0
#
# [85 rows x 14 columns]

# %%
time.loc["전체","2019"].T.sort_values(by="소계", ascending=False)
# Out:
#                        소계
# 구분별(1)
# 사례수 (명)            4457.7
# 10분 이상 30분 미만 (%)    43.3
# 30분 이상 1시간 미만 (%)    25.8
# 1시간 이상 2시간 미만 (%)    14.8
# 2시간 이상 (%)            7.6
# 5분 이상 10분 미만 (%)      7.3
# 5분 미만 (%)             1.1

# %%
time.loc["전체","2020"].T.sort_values(by="소계", ascending=False)
# Out:
#                        소계
# 구분별(1)
# 사례수 (명)            7434.0
# 10분 이상 30분 미만 (%)    33.1
# 30분 이상 1시간 미만 (%)    31.9
# 1시간 이상 2시간 미만 (%)    21.0
# 2시간 이상 (%)           11.9
# 5분 이상 10분 미만 (%)      2.0
# 5분 미만 (%)             0.2

# %%
# 하루에 1시간 미만으로 OTT서비스를 사용하는 사람들이 많고 빈도수는 하루에 여러 번 사용하는 사람들이 많다.
# 여러 영화 및 프로그램들은 1편 당 1시간 이상의 시간이 걸리는 경우가 많은데 이렇게 사용한다는 것은 끊어서 보는 경우가 많다고 할 수도 있다.
        # OTT서비스 주 이용 콘텐츠 참고(예능/오락, TV프로그램 등이 주를 이루고 있음)

# %% [markdown]
# ## OTT서비스 시청상황
#
# - OTT서비스를 언제(어떤 상황에서) 시청할까?

# %%
when = pd.read_excel("OTT서비스시청상황.xlsx", header=[0,1], index_col=[0])
# Out:
# C:\Users\gyeoa\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
when
# Out:
# 구분별(1)                                2015                                     \
# 구분별(1) TV가 없는 장소에서 특정 프로그램 본방을 사수하려할 때 (%) 이동 중이거나 자투리 시간에 남는 시간을 보내기 위해서 (%)
# 전체                                    44.4                               62.5
# 1위                                    25.2                               32.2
#
# 구분별(1)                                                              \
# 구분별(1) TV가 있는 장소에서 방송을 보고 싶을 때 (%) 시청하지 못한 TV프로그램을 나중에 시청하려할 때 (%)
# 전체                            39.1                            49.1
# 1위                            19.9                            19.0
#
# 구분별(1)                                2016                                     \
# 구분별(1) TV가 없는 장소에서 특정 프로그램 본방을 사수하려할 때 (%) 이동 중이거나 자투리 시간에 남는 시간을 보내기 위해서 (%)
# 전체                                    52.0                               60.0
# 1위                                    31.3                               28.4
#
# 구분별(1)                                                              \
# 구분별(1) TV가 있는 장소에서 방송을 보고 싶을 때 (%) 시청하지 못한 TV프로그램을 나중에 시청하려할 때 (%)
# 전체                            38.8                            40.1
# 1위                            21.2                            18.3
#
# 구분별(1)                                2017                                     \
# 구분별(1) TV가 없는 장소에서 특정 프로그램 본방을 사수하려할 때 (%) 이동 중이거나 자투리 시간에 남는 시간을 보내기 위해서 (%)
# 전체                                    50.8                               58.8
# 1위                                    32.5                               28.3
#
# 구분별(1)
# 구분별(1) TV가 있는 장소에서 방송을 보고 싶을 때 (%) 시청하지 못한 TV프로그램을 나중에 시청하려할 때 (%)
# 전체                            41.6                            41.2
# 1위                            21.5                            16.6

# %%
when.T.sort_values(by="전체", ascending=False)
# Out:
#                                               전체    1위
# 구분별(1) 구분별(1)
# 2015   이동 중이거나 자투리 시간에 남는 시간을 보내기 위해서 (%)   62.5  32.2
# 2016   이동 중이거나 자투리 시간에 남는 시간을 보내기 위해서 (%)   60.0  28.4
# 2017   이동 중이거나 자투리 시간에 남는 시간을 보내기 위해서 (%)   58.8  28.3
# 2016   TV가 없는 장소에서 특정 프로그램 본방을 사수하려할 때 (%)  52.0  31.3
# 2017   TV가 없는 장소에서 특정 프로그램 본방을 사수하려할 때 (%)  50.8  32.5
# 2015   시청하지 못한 TV프로그램을 나중에 시청하려할 때 (%)      49.1  19.0
#        TV가 없는 장소에서 특정 프로그램 본방을 사수하려할 때 (%)  44.4  25.2
# 2017   TV가 있는 장소에서 방송을 보고 싶을 때 (%)          41.6  21.5
#        시청하지 못한 TV프로그램을 나중에 시청하려할 때 (%)      41.2  16.6
# 2016   시청하지 못한 TV프로그램을 나중에 시청하려할 때 (%)      40.1  18.3
# 2015   TV가 있는 장소에서 방송을 보고 싶을 때 (%)          39.1  19.9
# 2016   TV가 있는 장소에서 방송을 보고 싶을 때 (%)          38.8  21.2

# %% [markdown]
# 예전 자료이긴 하지만 이동중이거나 자투리 시간에 남는 시간을 보내기 위해서가 가장 많은 분량을 차지한다.
#
# 이를 통해서 영상을 보는 시간이 끊어져 있는 이유가 이러한 상황에서 OTT서비스를 이용하기 때문에도 영향을 받았다고 생각해 볼 수 있다.

# %% [markdown]
# ### 해외 OTT서비스 비가입이유

# %%
reason = pd.read_csv("해외유료OTT서비스비가입이유.csv", encoding="euc-kr", index_col=[0,1,2,3,4])
reason
# Out:
#                        사례수(명)  이용요금이비싸서(비율)  특별히볼만한재미있고좋은콘텐츠가없어서(비율)  \
# 연번 조사연도 국가  분류  구분
# 1  2020 영국  국가별 전체         66          30.3                      6.1
# 2  2020 호주  국가별 전체        118          24.6                      3.4
# 3  2020 러시아 국가별 전체         59          28.8                      8.5
# 4  2020 브라질 국가별 전체         56          25.0                      3.6
# 5  2020 UAE 국가별 전체         55          14.5                      9.1
# ...                       ...           ...                      ...
# 91 2020 러시아 소득별 평균 이상       8          37.5                      0.0
# 92 2020 브라질 소득별 평균 이하      19          26.3                     10.5
# 93 2020 브라질 소득별 평균 이상      13           7.7                      0.0
# 94 2020 UAE 소득별 평균 이하      19          10.5                     10.5
# 95 2020 UAE 소득별 평균 이상      18          22.2                     11.1
#
#                        지상파TV나유료방송으로도충분해서(비율)  온라인동영상서비스(OTT)가만족스럽지않아서(비율)  \
# 연번 조사연도 국가  분류  구분
# 1  2020 영국  국가별 전체                      28.8                          1.5
# 2  2020 호주  국가별 전체                      29.7                          2.5
# 3  2020 러시아 국가별 전체                      32.2                          1.7
# 4  2020 브라질 국가별 전체                      19.6                          5.4
# 5  2020 UAE 국가별 전체                      16.4                          3.6
# ...                                      ...                          ...
# 91 2020 러시아 소득별 평균 이상                   25.0                         12.5
# 92 2020 브라질 소득별 평균 이하                   21.1                         10.5
# 93 2020 브라질 소득별 평균 이상                   30.8                          0.0
# 94 2020 UAE 소득별 평균 이하                   15.8                          5.3
# 95 2020 UAE 소득별 평균 이상                   11.1                          0.0
#
#                        가입방법을잘몰라서(비율)  이용방법을잘몰라서(비율)  콘텐츠품질이떨어져서(비율)  \
# 연번 조사연도 국가  분류  구분
# 1  2020 영국  국가별 전체               1.5            9.1             0.0
# 2  2020 호주  국가별 전체               5.1            7.6             0.8
# 3  2020 러시아 국가별 전체               5.1            6.8             1.7
# 4  2020 브라질 국가별 전체              14.3           10.7             0.0
# 5  2020 UAE 국가별 전체              12.7            9.1             5.5
# ...                              ...            ...             ...
# 91 2020 러시아 소득별 평균 이상           12.5            0.0             0.0
# 92 2020 브라질 소득별 평균 이하           15.8            0.0             0.0
# 93 2020 브라질 소득별 평균 이상           23.1            7.7             0.0
# 94 2020 UAE 소득별 평균 이하           10.5           10.5             0.0
# 95 2020 UAE 소득별 평균 이상           16.7           11.1             5.6
#
#                        자녀들에게부정적인영향을미칠것같아서(비율)  외국서비스를이용하는것을좋아하지않아서(비율)
# 연번 조사연도 국가  분류  구분
# 1  2020 영국  국가별 전체                        3.0                      6.1
# 2  2020 호주  국가별 전체                        1.7                      7.6
# 3  2020 러시아 국가별 전체                        0.0                      1.7
# 4  2020 브라질 국가별 전체                        1.8                      3.6
# 5  2020 UAE 국가별 전체                        3.6                     12.7
# ...                                       ...                      ...
# 91 2020 러시아 소득별 평균 이상                     0.0                     12.5
# 92 2020 브라질 소득별 평균 이하                     5.3                      0.0
# 93 2020 브라질 소득별 평균 이상                     0.0                     15.4
# 94 2020 UAE 소득별 평균 이하                     0.0                     15.8
# 95 2020 UAE 소득별 평균 이상                     5.6                     16.7
#
# [95 rows x 10 columns]

# %%
reason1 = reason.iloc[0:5].droplevel(["연번","조사연도","분류", "구분"]).T
reason1
# Out:
# 국가                             영국     호주   러시아   브라질   UAE
# 사례수(명)                       66.0  118.0  59.0  56.0  55.0
# 이용요금이비싸서(비율)                 30.3   24.6  28.8  25.0  14.5
# 특별히볼만한재미있고좋은콘텐츠가없어서(비율)       6.1    3.4   8.5   3.6   9.1
# 지상파TV나유료방송으로도충분해서(비율)        28.8   29.7  32.2  19.6  16.4
# 온라인동영상서비스(OTT)가만족스럽지않아서(비율)   1.5    2.5   1.7   5.4   3.6
# 가입방법을잘몰라서(비율)                 1.5    5.1   5.1  14.3  12.7
# 이용방법을잘몰라서(비율)                 9.1    7.6   6.8  10.7   9.1
# 콘텐츠품질이떨어져서(비율)                0.0    0.8   1.7   0.0   5.5
# 자녀들에게부정적인영향을미칠것같아서(비율)        3.0    1.7   0.0   1.8   3.6
# 외국서비스를이용하는것을좋아하지않아서(비율)       6.1    7.6   1.7   3.6  12.7

# %%
England = reason1.sort_values("영국", ascending=False)["영국"].head()
Austrailia = reason1.sort_values("호주", ascending=False)["호주"].head()
Russia = reason1.sort_values("러시아", ascending=False)["러시아"].head()
Brazil = reason1.sort_values("브라질", ascending=False)["브라질"].head()
UAE = reason1.sort_values("UAE", ascending=False)["UAE"].head()

list1 = [England, Austrailia, Russia, Brazil, UAE]

reasontotal = pd.concat(list1, axis=1)
reasontotal
# Out:
#                            영국     호주   러시아   브라질   UAE
# 사례수(명)                   66.0  118.0  59.0  56.0  55.0
# 이용요금이비싸서(비율)             30.3   24.6  28.8  25.0  14.5
# 지상파TV나유료방송으로도충분해서(비율)    28.8   29.7  32.2  19.6  16.4
# 이용방법을잘몰라서(비율)             9.1    7.6   6.8  10.7   NaN
# 특별히볼만한재미있고좋은콘텐츠가없어서(비율)   6.1    NaN   8.5   NaN   NaN
# 외국서비스를이용하는것을좋아하지않아서(비율)   NaN    7.6   NaN   NaN  12.7
# 가입방법을잘몰라서(비율)             NaN    NaN   NaN  14.3  12.7

# %% [markdown]
# 영국과 브라질의 이용요금이 비싸서라는 이유가 가장 높음
#
# 다른 나라의 경우 지상파TV나 유료방송으로도 충분해서라는 비율이 가장 높았지만
# 사실 둘의 차이는 크지 않다고 생각된다.

# %% [markdown]
# ## 영화관 티켓가격 정리

# %%
# https://post.naver.com/viewer/postView.naver?volumeNo=31753842&memberNo=31724756

# 2000.12월 6000 >7000원,
# 2008.5월 8000원
# 2009.7월 9000원
# 2013.2월 10000원
# 2014.2월 10000원(2D, 3D차등제 실시)
# 2016.4월 11000원(프라임존)
# 2018.4월 12000원(프라임존)
# 2020.10월 13000원(좌석 차등제 폐지)
# 2021.3월 14000원

# %%
eight1 = pd.read_excel("data/2008년월별영화관객수.xlsx", skiprows = 4, header=[0,1])
eight1 = eight1.iloc[:, [0,-1]].droplevel(level=1, axis=1)
eight1.columns = ["년월","관람객수"]
eight1 = eight1.iloc[0:12]
eight1["년월"]=pd.to_datetime(eight1["년월"])
eight1["년월"] = eight1["년월"].dt.strftime("%Y-%m")
eight1
# Out:
#          년월      관람객수
# 0   2008-01  12851835
# 1   2008-02  12845088
# 2   2008-03   9606955
# 3   2008-04   7330006
# 4   2008-05  12870573
# 5   2008-06  14227212
# 6   2008-07  17033494
# 7   2008-08  17369947
# 8   2008-09  10945140
# 9   2008-10   8744625
# 10  2008-11   9472588
# 11  2008-12  14131176

# %%
nine = pd.read_excel("data/2009년월별영화관객수.xlsx", skiprows = 4, header=[0,1])
nine = nine.iloc[:, [0,-1]].droplevel(level=1, axis=1)
nine.columns = ["년월","관람객수"]
nine = nine.iloc[0:12]
nine["년월"]=pd.to_datetime(nine["년월"])
nine["년월"] = nine["년월"].dt.strftime("%Y-%m")
nine
# Out:
#          년월      관람객수
# 0   2009-01  16525594
# 1   2009-02  11156302
# 2   2009-03   7832797
# 3   2009-04   7848673
# 4   2009-05  16146532
# 5   2009-06  12963482
# 6   2009-07  16349119
# 7   2009-08  21418297
# 8   2009-09   8336580
# 9   2009-10   9357086
# 10  2009-11  10665552
# 11  2009-12  16798640

# %%
twelve = pd.read_excel("data/2012년월별영화관객수.xlsx", skiprows = 4, header=[0,1])
twelve = twelve.iloc[:, [0,-1]].droplevel(level=1, axis=1)
twelve.columns = ["년월","관람객수"]
twelve = twelve.iloc[0:12]
twelve["년월"]=pd.to_datetime(twelve["년월"])
twelve["년월"]= twelve["년월"].dt.strftime("%Y-%m")
twelve
# Out:
#          년월      관람객수
# 0   2012-01  16628650
# 1   2012-02  13065438
# 2   2012-03  11392750
# 3   2012-04  11993363
# 4   2012-05  15970116
# 5   2012-06  14211515
# 6   2012-07  20964476
# 7   2012-08  24238713
# 8   2012-09  14597393
# 9   2012-10  15288721
# 10  2012-11  15947251
# 11  2012-12  20592201

# %%
thirteen = pd.read_excel("data/2013년월별영화관객수.xlsx", skiprows = 4, header=[0,1])
thirteen = thirteen.iloc[:, [0,-1]].droplevel(level=1, axis=1)
thirteen.columns = ["년월","관람객수"]
thirteen = thirteen.iloc[0:12]
thirteen["년월"]=pd.to_datetime(thirteen["년월"])
thirteen["년월"] = thirteen["년월"].dt.strftime("%Y-%m")
thirteen
# Out:
#          년월      관람객수
# 0   2013-01  20366773
# 1   2013-02  21824737
# 2   2013-03  13283201
# 3   2013-04  11259977
# 4   2013-05  14211968
# 5   2013-06  17555734
# 6   2013-07  18824441
# 7   2013-08  29142663
# 8   2013-09  19234287
# 9   2013-10  13490691
# 10  2013-11  13380122
# 11  2013-12  20776436

# %%
fourteen = pd.read_excel("data/2014년월별영화관객수.xlsx", skiprows = 4, header=[0,1])
fourteen = fourteen.iloc[:, [0,-1]].droplevel(level=1, axis=1)
fourteen.columns = ["년월","관람객수"]
fourteen = fourteen.iloc[0:12]
fourteen["년월"]=pd.to_datetime(fourteen["년월"])
fourteen["년월"] = fourteen["년월"].dt.strftime("%Y-%m")
fourteen
# Out:
#          년월      관람객수
# 0   2014-01  23596599
# 1   2014-02  18558381
# 2   2014-03  12404922
# 3   2014-04   9206484
# 4   2014-05  16862099
# 5   2014-06  15889312
# 6   2014-07  19876822
# 7   2014-08  32219304
# 8   2014-09  17084849
# 9   2014-10  12502773
# 10  2014-11  15190407
# 11  2014-12  21677006

# %%
fifthteen = pd.read_excel("data/2015년월별영화관객수.xlsx", skiprows = 4, header=[0,1])
fifthteen = fifthteen.iloc[:, [0,-1]].droplevel(level=1, axis=1)
fifthteen.columns = ["년월","관람객수"]
fifthteen = fifthteen.iloc[0:12]
fifthteen["년월"]=pd.to_datetime(fifthteen["년월"])
fifthteen["년월"] = fifthteen["년월"].dt.strftime("%Y-%m")
fifthteen
# Out:
#          년월      관람객수
# 0   2015-01  22484091
# 1   2015-02  16666173
# 2   2015-03  11323107
# 3   2015-04  12721639
# 4   2015-05  17670740
# 5   2015-06  14201957
# 6   2015-07  23431726
# 7   2015-08  30902141
# 8   2015-09  18733043
# 9   2015-10  14926529
# 10  2015-11  15275978
# 11  2015-12  18962399

# %%
six = pd.read_excel("data/2016년월별영화관객수.xlsx", skiprows = 4, header=[0,1])
six = six.iloc[:, [0,-1]].droplevel(level=1, axis=1)
six.columns = ["년월","관람객수"]
six = six.iloc[0:12]
six["년월"]=pd.to_datetime(six["년월"])
six["년월"] = six["년월"].dt.strftime("%Y-%m")
six
# Out:
#          년월      관람객수
# 0   2016-01  16908582
# 1   2016-02  21312706
# 2   2016-03  11266732
# 3   2016-04   9995372
# 4   2016-05  18131197
# 5   2016-06  17020069
# 6   2016-07  26237872
# 7   2016-08  29940921
# 8   2016-09  16208794
# 9   2016-10  17159928
# 10  2016-11  12682819
# 11  2016-12  20161190

# %%
seven = pd.read_excel("data/2017년월별영화관객수.xlsx", skiprows = 4, header=[0,1])
seven = seven.iloc[:, [0,-1]].droplevel(level=1, axis=1)
seven.columns = ["년월","관람객수"]
seven = seven.iloc[0:12]
seven["년월"]=pd.to_datetime(seven["년월"])
seven["년월"] = seven["년월"].dt.strftime("%Y-%m")
seven
# Out:
#          년월      관람객수
# 0   2017-01  23255258
# 1   2017-02  15181395
# 2   2017-03  13855445
# 3   2017-04  11214167
# 4   2017-05  18680206
# 5   2017-06  15103839
# 6   2017-07  21357163
# 7   2017-08  29885346
# 8   2017-09  12719893
# 9   2017-10  21585909
# 10  2017-11  13155930
# 11  2017-12  23881676

# %%
eight = pd.read_excel("data/2018년월별영화관객수.xlsx", skiprows = 4, header=[0,1])
eight = eight.iloc[:, [0,-1]].droplevel(level=1, axis=1)
eight.columns = ["년월","관람객수"]
eight = eight.iloc[0:12]
eight["년월"]=pd.to_datetime(eight["년월"])
eight["년월"] = eight["년월"].dt.strftime("%Y-%m")
eight
# Out:
#          년월      관람객수
# 0   2018-01  22943456
# 1   2018-02  15551760
# 2   2018-03  12801511
# 3   2018-04  14066243
# 4   2018-05  15891715
# 5   2018-06  15099844
# 6   2018-07  19776669
# 7   2018-08  30258275
# 8   2018-09  16823946
# 9   2018-10  14075357
# 10  2018-11  17149948
# 11  2018-12  21946545

# %%
nine1 = pd.read_excel("data/2019영화관람객수.xlsx", skiprows = 4, header=[0,1])
nine1 = nine1.iloc[:, [0,-1]].droplevel(level=1, axis=1)
nine1.columns = ["년월","관람객수"]
nine1 = nine1.iloc[0:12]
nine1["년월"]=pd.to_datetime(nine1["년월"])
nine1["년월"] = nine1["년월"].dt.strftime("%Y-%m")
nine1
# Out:
#          년월      관람객수
# 0   2019-01  18122443
# 1   2019-02  22277733
# 2   2019-03  14671693
# 3   2019-04  13338962
# 4   2019-05  18062457
# 5   2019-06  22845579
# 6   2019-07  21916465
# 7   2019-08  24786121
# 8   2019-09  14733642
# 9   2019-10  14858383
# 10  2019-11  18600679
# 11  2019-12  22464620

# %%
ten1 = pd.read_excel("data/2020영화관람객수.xlsx", skiprows = 4, header=[0,1])
ten1 = ten1.iloc[:, [0,-1]].droplevel(level=1, axis=1)
ten1.columns = ["년월","관람객수"]
ten1 = ten1.iloc[0:12]
ten1["년월"]=pd.to_datetime(ten1["년월"])
ten1["년월"] = ten1["년월"].dt.strftime("%Y-%m")
ten1
# Out:
#          년월      관람객수
# 0   2020-01  16843695
# 1   2020-02   7372370
# 2   2020-03   1834722
# 3   2020-04    972572
# 4   2020-05   1526236
# 5   2020-06   3864533
# 6   2020-07   5618701
# 7   2020-08   8834699
# 8   2020-09   2988647
# 9   2020-10   4633609
# 10  2020-11   3595310
# 11  2020-12   1438873

# %%
eleven = pd.read_excel("data/2021영화관람객수.xlsx", skiprows = 4, header=[0,1])
eleven = eleven.iloc[:, [0,-1]].droplevel(level=1, axis=1)
eleven.columns = ["년월","관람객수"]
eleven = eleven.iloc[0:12]
eleven["년월"]=pd.to_datetime(eleven["년월"])
eleven["년월"] = eleven["년월"].dt.strftime("%Y-%m")
eleven
# Out:
#          년월     관람객수
# 0   2021-01  1786117
# 1   2021-02  3111920
# 2   2021-03  3256510
# 3   2021-04  2562285
# 4   2021-05  4379476
# 5   2021-06  4927990
# 6   2021-07  6976451
# 7   2021-08  7910082
# 8   2021-09  5412319
# 9   2021-10  5192139
# 10  2021-11  6512815
# 11  2021-12  8502983

# %%
total2 = pd.concat([nine1, ten1, eleven])
total2 = total2.reset_index(drop=True)

# %%
total = pd.concat([eight1, nine, twelve, thirteen, fourteen, fifthteen, six, seven, eight])

# %%
total1 = total.reset_index(drop=True)

# %%
total1[total1["년월"].isin(["2008-05","2009-07","2013-02","2014-02","2016-04","2018-04"])]
# Out:
#          년월      관람객수
# 4   2008-05  12870573
# 18  2009-07  16349119
# 37  2013-02  21824737
# 49  2014-02  18558381
# 75  2016-04   9995372
# 99  2018-04  14066243

# %%
plt.figure(figsize=(30, 25))

total1.plot(figsize = (25,15))
plt.axvline(x=4, color = "r")
plt.axvline(x=18, color = "r")
plt.axvline(x=37, color = "r")
plt.axvline(x=49, color = "r")
#plt.axvline(x=75, color = "r")
plt.axvline(x=99, color = "r")

plt.show()
# #강조하고 싶을 때 수직선 긋는 방법(plt.axvline)

# plt.text(6, 200, "출근")
# plt.text(16,200, "퇴근")
# #그래프 안에 글씨 쓰기(plt.text)

# 주말 2D가격 기준
# 2000.12월 6000 >7000원,
# 2008.5월 8000원
# 2009.7월 9000원
# 2013.2월 10000원
# 2014.2월 10000원(2D, 3D차등제 실시)
# 2016.4월 11000원(프라임존), 스탠다드 10000원 그대로
# 2018.4월 12000원(프라임존), 스탠다드 11000원(1000원 인상)
# 2020.10월 13000원(좌석 차등제 폐지)
# 2021.3월 14000원

# %%
plt.figure(figsize=(30, 25))

total2.plot()
plt.axvline(x=21, color = "r")
plt.axvline(x=26, color = "r")

# %%
final = pd.concat([total1, total2])

# %%
final = final.reset_index(drop=True)
final[final["년월"].isin(["2008-05","2009-07","2013-02","2014-02","2016-04","2018-04","2020-10","2021-03"])]
# Out:
#           년월      관람객수
# 4    2008-05  12870573
# 18   2009-07  16349119
# 37   2013-02  21824737
# 49   2014-02  18558381
# 75   2016-04   9995372
# 99   2018-04  14066243
# 129  2020-10   4633609
# 134  2021-03   3256510

# %%
final = final.set_index("년월")

# %%
final.to_csv("월별관람객수.csv")
final = pd.read_csv("월별관람객수.csv", index_col=[0])
final.head()
# Out:
#              관람객수
# 년월
# 2008-01  12851835
# 2008-02  12845088
# 2008-03   9606955
# 2008-04   7330006
# 2008-05  12870573

# %%
final.plot(figsize = (25,15))
plt.axvline(x=4, color = "black")
plt.axvline(x=18, color = "black")
plt.axvline(x=37, color = "black")
plt.axvline(x=49, color = "black")
#plt.axvline(x=75, color = "r") >> 가격이 오르지는 않고 가격 체계가 바뀜
plt.axvline(x=99, color = "r")
plt.axvline(x=129, color = "black")
plt.axvline(x=134, color = "black")

# 주말 2D가격 기준
# 2000.12월 6000 >7000원,
# 2008.5월 8000원
# 2009.7월 9000원
# 2013.2월 10000원
# 2014.2월 10000원(2D, 3D차등제 실시)
# 2016.4월 11000원(프라임존), 스탠다드 10000원 그대로
# 2018.4월 12000원(프라임존), 스탠다드 11000원(1000원 인상)
# 2020.10월 13000원(좌석 차등제 폐지)
# 2021.3월 14000원

# 가격이 10000원이 넘어간 이후 가격이 오를 때마다 관객수가 떨어짐
# 2018년 4월에는 가격이 떨어짐에도 불구하고 오른 관객수가 증가했는데
    # 이때는 '어벤져스:인피니티워'가 개봉한 달로 특수 상황이라고 볼 수 있다.

# %%
total2
# Out:
#          년월      관람객수
# 0   2019-01  18122443
# 1   2019-02  22277733
# 2   2019-03  14671693
# 3   2019-04  13338962
# 4   2019-05  18062457
# 5   2019-06  22845579
# 6   2019-07  21916465
# 7   2019-08  24786121
# 8   2019-09  14733642
# 9   2019-10  14858383
# 10  2019-11  18600679
# 11  2019-12  22464620
# 12  2020-01  16843695
# 13  2020-02   7372370
# 14  2020-03   1834722
# 15  2020-04    972572
# 16  2020-05   1526236
# 17  2020-06   3864533
# 18  2020-07   5618701
# 19  2020-08   8834699
# 20  2020-09   2988647
# 21  2020-10   4633609
# 22  2020-11   3595310
# 23  2020-12   1438873
# 24  2021-01   1786117
# 25  2021-02   3111920
# 26  2021-03   3256510
# 27  2021-04   2562285
# 28  2021-05   4379476
# 29  2021-06   4927990
# 30  2021-07   6976451
# 31  2021-08   7910082
# 32  2021-09   5412319
# 33  2021-10   5192139
# 34  2021-11   6512815
# 35  2021-12   8502983

# %%
corona = pd.read_csv("data/전국코로나확진자수.csv", index_col = [0])
corona
# Out:
#     year  month       covid
# 0   2020      3      5560.0
# 1   2020      4      1241.0
# 2   2020      5       703.0
# 3   2020      6      1385.0
# 4   2020      7      1509.0
# 5   2020      8      5685.0
# 6   2020      9      4051.0
# 7   2020     10      2864.0
# 8   2020     11      8219.0
# 9   2020     12     32638.0
# 10  2021      1     18215.0
# 11  2021      2     11827.0
# 12  2021      3     13430.0
# 13  2021      4     20148.0
# 14  2021      5     17356.0
# 15  2021      6     16109.0
# 16  2021      7     42035.0
# 17  2021      8     54897.0
# 18  2021      9     59899.0
# 19  2021     10     53450.0
# 20  2021     11     85232.0
# 21  2021     12    183680.0
# 22  2022      1    215009.0
# 23  2022      2   2288947.0
# 24  2022      3  11363545.0
# 25  2022      4   4270563.0
# 26  2022      5    866392.0
# 27  2022      6    259639.0
# 28  2022      7   1406796.0
# 29  2022      8   3540725.0
# 30  2022      9   1454451.0
# 31  2022     10    771880.0
# 32  2022     11   1024942.0

# %%
index = total2["년월"][14:].values
index
# Out:
# array(['2020-03', '2020-04', '2020-05', '2020-06', '2020-07', '2020-08',
#        '2020-09', '2020-10', '2020-11', '2020-12', '2021-01', '2021-02',
#        '2021-03', '2021-04', '2021-05', '2021-06', '2021-07', '2021-08',
#        '2021-09', '2021-10', '2021-11', '2021-12'], dtype=object)

# %%
corona = corona.iloc[0:22,:]

corona["년월"]=index
corona = corona.iloc[:,2:4]
corona
# Out:
# C:\Users\gyeoa\AppData\Local\Temp\ipykernel_11840\4096712222.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   corona["년월"]=index
#        covid       년월
# 0     5560.0  2020-03
# 1     1241.0  2020-04
# 2      703.0  2020-05
# 3     1385.0  2020-06
# 4     1509.0  2020-07
# 5     5685.0  2020-08
# 6     4051.0  2020-09
# 7     2864.0  2020-10
# 8     8219.0  2020-11
# 9    32638.0  2020-12
# 10   18215.0  2021-01
# 11   11827.0  2021-02
# 12   13430.0  2021-03
# 13   20148.0  2021-04
# 14   17356.0  2021-05
# 15   16109.0  2021-06
# 16   42035.0  2021-07
# 17   54897.0  2021-08
# 18   59899.0  2021-09
# 19   53450.0  2021-10
# 20   85232.0  2021-11
# 21  183680.0  2021-12

# %%
num = [564]
for i in range(int(len(corona)-1)):
    a = corona["c_count"][i+1]-corona["c_count"][i]
    num.append(a)
corona["당월확진자수"] = num
corona
# Out:
#     c_count       년월   당월확진자수
# 0       564  2020-02      564
# 1      7699  2020-03     7135
# 2     17931  2020-04    10232
# 3     22484  2020-05     4553
# 4     33379  2020-06    10895
# 5     45246  2020-07    11867
# 6     72061  2020-08    26815
# 7    142008  2020-09    69947
# 8    174720  2020-10    32712
# 9    210736  2020-11    36016
# 10   417304  2020-12   206568
# 11   686445  2021-01   269141
# 12   736241  2021-02    49796
# 13   934927  2021-03   198686
# 14  1048475  2021-04   113548
# 15  1310996  2021-05   262521
# 16  1407501  2021-06    96505
# 17  1770523  2021-07   363022
# 18  2226916  2021-08   456393
# 19  2675873  2021-09   448957
# 20  3430507  2021-10   754634
# 21  4049959  2021-11   619452
# 22  5960209  2021-12  1910250

# %%
total3 = total2.merge(corona, left_on="년월", right_on="년월")
total3["확진자10"] = total3["covid"]*100
total4 = total3[["년월","관람객수","확진자10"]]
total4
# Out:
#          년월     관람객수       확진자10
# 0   2020-03  1834722    556000.0
# 1   2020-04   972572    124100.0
# 2   2020-05  1526236     70300.0
# 3   2020-06  3864533    138500.0
# 4   2020-07  5618701    150900.0
# 5   2020-08  8834699    568500.0
# 6   2020-09  2988647    405100.0
# 7   2020-10  4633609    286400.0
# 8   2020-11  3595310    821900.0
# 9   2020-12  1438873   3263800.0
# 10  2021-01  1786117   1821500.0
# 11  2021-02  3111920   1182700.0
# 12  2021-03  3256510   1343000.0
# 13  2021-04  2562285   2014800.0
# 14  2021-05  4379476   1735600.0
# 15  2021-06  4927990   1610900.0
# 16  2021-07  6976451   4203500.0
# 17  2021-08  7910082   5489700.0
# 18  2021-09  5412319   5989900.0
# 19  2021-10  5192139   5345000.0
# 20  2021-11  6512815   8523200.0
# 21  2021-12  8502983  18368000.0

# %%
total3
# Out:
#          년월     관람객수     covid       확진자10
# 0   2020-03  1834722    5560.0    556000.0
# 1   2020-04   972572    1241.0    124100.0
# 2   2020-05  1526236     703.0     70300.0
# 3   2020-06  3864533    1385.0    138500.0
# 4   2020-07  5618701    1509.0    150900.0
# 5   2020-08  8834699    5685.0    568500.0
# 6   2020-09  2988647    4051.0    405100.0
# 7   2020-10  4633609    2864.0    286400.0
# 8   2020-11  3595310    8219.0    821900.0
# 9   2020-12  1438873   32638.0   3263800.0
# 10  2021-01  1786117   18215.0   1821500.0
# 11  2021-02  3111920   11827.0   1182700.0
# 12  2021-03  3256510   13430.0   1343000.0
# 13  2021-04  2562285   20148.0   2014800.0
# 14  2021-05  4379476   17356.0   1735600.0
# 15  2021-06  4927990   16109.0   1610900.0
# 16  2021-07  6976451   42035.0   4203500.0
# 17  2021-08  7910082   54897.0   5489700.0
# 18  2021-09  5412319   59899.0   5989900.0
# 19  2021-10  5192139   53450.0   5345000.0
# 20  2021-11  6512815   85232.0   8523200.0
# 21  2021-12  8502983  183680.0  18368000.0

# %%
number = total3[["년월","관람객수","covid"]]
number
movie = [0]
corona = [0]
for i in range(1,int(len(number))):
    movie.append((number["관람객수"][i]-number["관람객수"][i-1])/number["관람객수"][i-1])
    corona.append((number["covid"][i]-number["covid"][i-1])/number["covid"][i-1])

rate = number.copy()    
rate["확진자수증감"] = corona
rate["관람객수증감"] = movie
rate
# Out:
#          년월     관람객수     covid    확진자수증감    관람객수증감
# 0   2020-03  1834722    5560.0  0.000000  0.000000
# 1   2020-04   972572    1241.0 -0.776799 -0.469908
# 2   2020-05  1526236     703.0 -0.433521  0.569278
# 3   2020-06  3864533    1385.0  0.970128  1.532068
# 4   2020-07  5618701    1509.0  0.089531  0.453915
# 5   2020-08  8834699    5685.0  2.767396  0.572374
# 6   2020-09  2988647    4051.0 -0.287423 -0.661715
# 7   2020-10  4633609    2864.0 -0.293014  0.550404
# 8   2020-11  3595310    8219.0  1.869763 -0.224080
# 9   2020-12  1438873   32638.0  2.971043 -0.599792
# 10  2021-01  1786117   18215.0 -0.441908  0.241331
# 11  2021-02  3111920   11827.0 -0.350700  0.742282
# 12  2021-03  3256510   13430.0  0.135537  0.046463
# 13  2021-04  2562285   20148.0  0.500223 -0.213181
# 14  2021-05  4379476   17356.0 -0.138575  0.709207
# 15  2021-06  4927990   16109.0 -0.071848  0.125246
# 16  2021-07  6976451   42035.0  1.609411  0.415679
# 17  2021-08  7910082   54897.0  0.305983  0.133826
# 18  2021-09  5412319   59899.0  0.091116 -0.315770
# 19  2021-10  5192139   53450.0 -0.107665 -0.040681
# 20  2021-11  6512815   85232.0  0.594612  0.254361
# 21  2021-12  8502983  183680.0  1.155059  0.305577

# %%
number.to_csv("data/영화코로나.csv", index=False)

# %%
rate1 = rate[["확진자수증감","관람객수증감"]]
rate1
rate1.to_csv("data/전국증감률.csv", index=False)

# %%
rate1 = pd.read_csv("data/전국증감률.csv")
rate1
# Out:
#       확진자수증감    관람객수증감
# 0   0.000000  0.000000
# 1  -0.776799 -0.469908
# 2  -0.433521  0.569278
# 3   0.970128  1.532068
# 4   0.089531  0.453915
# 5   2.767396  0.572374
# 6  -0.287423 -0.661715
# 7  -0.293014  0.550404
# 8   1.869763 -0.224080
# 9   2.971043 -0.599792
# 10 -0.441908  0.241331
# 11 -0.350700  0.742282
# 12  0.135537  0.046463
# 13  0.500223 -0.213181
# 14 -0.138575  0.709207
# 15 -0.071848  0.125246
# 16  1.609411  0.415679
# 17  0.305983  0.133826
# 18  0.091116 -0.315770
# 19 -0.107665 -0.040681
# 20  0.594612  0.254361
# 21  1.155059  0.305577

# %%
rate1.index = rate["년월"]
rate1
# Out:
#            확진자수증감    관람객수증감
# 년월
# 2020-03  0.000000  0.000000
# 2020-04 -0.776799 -0.469908
# 2020-05 -0.433521  0.569278
# 2020-06  0.970128  1.532068
# 2020-07  0.089531  0.453915
# 2020-08  2.767396  0.572374
# 2020-09 -0.287423 -0.661715
# 2020-10 -0.293014  0.550404
# 2020-11  1.869763 -0.224080
# 2020-12  2.971043 -0.599792
# 2021-01 -0.441908  0.241331
# 2021-02 -0.350700  0.742282
# 2021-03  0.135537  0.046463
# 2021-04  0.500223 -0.213181
# 2021-05 -0.138575  0.709207
# 2021-06 -0.071848  0.125246
# 2021-07  1.609411  0.415679
# 2021-08  0.305983  0.133826
# 2021-09  0.091116 -0.315770
# 2021-10 -0.107665 -0.040681
# 2021-11  0.594612  0.254361
# 2021-12  1.155059  0.305577

# %%
patient = rate1["확진자수증감"][0:21]
client = rate1["관람객수증감"][1:22]
client
effect = pd.DataFrame({"확진자수증감":patient, "관람객수증감":client})
#effect.to_csv("data/다음달영향.csv", index=False)

# %%
effect.index[0:-1]
# Out:
# Index(['2020-03', '2020-04', '2020-05', '2020-06', '2020-07', '2020-08',
#        '2020-09', '2020-10', '2020-11', '2020-12', '2021-01', '2021-02',
#        '2021-03', '2021-04', '2021-05', '2021-06', '2021-07', '2021-08',
#        '2021-09', '2021-10', '2021-11'],
#       dtype='object', name='년월')

# %%
patient.index = effect.index[1:]
patient
# Out:
# 년월
# 2020-04    0.000000
# 2020-05   -0.776799
# 2020-06   -0.433521
# 2020-07    0.970128
# 2020-08    0.089531
# 2020-09    2.767396
# 2020-10   -0.287423
# 2020-11   -0.293014
# 2020-12    1.869763
# 2021-01    2.971043
# 2021-02   -0.441908
# 2021-03   -0.350700
# 2021-04    0.135537
# 2021-05    0.500223
# 2021-06   -0.138575
# 2021-07   -0.071848
# 2021-08    1.609411
# 2021-09    0.305983
# 2021-10    0.091116
# 2021-11   -0.107665
# 2021-12    0.594612
# Name: 확진자수증감, dtype: float64

# %%
effect_final = pd.DataFrame({"확진자수증감":patient, "관람객수증감":client})

effect_final.columns = ["지난달확진자수증감률","이번달관람객수증감률"]
effect_final
# Out:
#          지난달확진자수증감률  이번달관람객수증감률
# 년월
# 2020-04    0.000000   -0.469908
# 2020-05   -0.776799    0.569278
# 2020-06   -0.433521    1.532068
# 2020-07    0.970128    0.453915
# 2020-08    0.089531    0.572374
# 2020-09    2.767396   -0.661715
# 2020-10   -0.287423    0.550404
# 2020-11   -0.293014   -0.224080
# 2020-12    1.869763   -0.599792
# 2021-01    2.971043    0.241331
# 2021-02   -0.441908    0.742282
# 2021-03   -0.350700    0.046463
# 2021-04    0.135537   -0.213181
# 2021-05    0.500223    0.709207
# 2021-06   -0.138575    0.125246
# 2021-07   -0.071848    0.415679
# 2021-08    1.609411    0.133826
# 2021-09    0.305983   -0.315770
# 2021-10    0.091116   -0.040681
# 2021-11   -0.107665    0.254361
# 2021-12    0.594612    0.305577

# %%
plt.figure(figsize=(30, 25))

rate1.plot()
# Out:
# <AxesSubplot:>

# %%
effect_final.plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='년월'>

# %%
client = rate1["관람객수증감"][1:22]


plt.figure(figsize=(15, 10))

patient.plot()
client.plot()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(30, 25))

total4.plot()
plt.axvline(x=8, color = "r")
plt.axvline(x=13, color = "r")
plt.text(3, 5, "11000원")
plt.text(9, 200, "13000원")
plt.text(15,200, "14000원")


# 2000.12월 6000 >7000원,
# 2008.5월 8000원
# 2009.7월 9000원
# 2013.2월 10000원
# 2014.2월 10000원(2D, 3D차등제 실시)
# 2016.4월 11000원(프라임존)
# 2018.4월 12000원(프라임존)
# 2020.10월 13000원(좌석 차등제 폐지)
# 2021.3월 14000원
# Out:
# Text(15, 200, '14000원')

# %%
# 코로나 확진자 수
