# %%
import requests
import xml.etree.ElementTree as et
#molit = requests.get("http://www.molit.go.kr/dev/board/board_rss.jsp?rss_id=N01_B")

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
board = et.fromstring(molit.text)
item = board.find("channel").findall("item")
for i in item:
    print(i.find("title").text, "\n", i.find("link").text)

# %%
url = "https://search.naver.com/search.naver?query=%EC%BD%94%EB%A1%9C%EB%82%98%EA%B1%B0%EB%A6%AC%EB%91%90%EA%B8%B0&nso=p%3Afrom20200201to20201231&where=view&sm=tab_nmr&mode=normal"
#page = requests.get(url)
#soup = BeautifulSoup(page.text, "html.parser")
    
#detail = soup.find("div", class_="status_wrap").get_text()

# %%
page = urlopen("https://search.naver.com/search.naver?query=%EC%BD%94%EB%A1%9C%EB%82%98%EA%B1%B0%EB%A6%AC%EB%91%90%EA%B8%B0&nso=p%3Afrom20200201to20201231&where=view&sm=tab_nmr&mode=normal")
soup = BeautifulSoup(page, "html.parser")

# %%
title = soup.find("ul", class_ = "_list_base").find_all("a", class_="api_txt_lines")

# %%
blog20 = []
for i in range(int(len(title))):
    text = title[i].get_text()
    blog20.append(text)
    
blog20
# Out:
# ['코로나 3단계 조치 검토 거리두기 기준 학원 학교 마트 결혼식 등',
#  '코로나 거리두기 2.5단계 격상 기준 및 방역조치',
#  '코로나발표, 2단계 +a 거리두기 상향? 어떤 점이 달라졌을까?',
#  '마포 필라테스 코로나 거리두기 2.5단계 홈 필라테스로 우울감, 두려움 이겨내보아요!!',
#  '코로나 거리두기 2.5단계 헬스장, 3단계 학교, 학원 집합금지',
#  '코로나 거리두기 억울한느낌..',
#  '사회적 거리두기에 안일함을 가진다면[코로나19 파견 간호사 일기] 돌봄의 가치, 코로나시대',
#  '[코로나 2단계 카페] 사회적 거리두기 2단계 적용시 개인카페도 취식 불가능!',
#  '코로나 거리두기 3단계 격상?! :: 기준 및 조치 (feat. 결혼식장, 장례식장,재택근무 의무화)',
#  '[코로나 2단계] 사회적 거리두기 2단계 총정리! 결혼식, 헬스장, 카페는?',
#  '코로나19 사회적거리두기2단계 2.5단계란?',
#  '코로나 거리두기 격상 모텔(호텔)엔 호재 VS 악재?',
#  '코로나 1.5단계 적용? 새로 바뀐 사회적 거리두기 5단계',
#  '예패))코로나 거리두기 관련요',
#  '코로나 거리두기에 대한 생각들,,',
#  '코로나 거리두기 3단계 격상 기준 & 달라지는 점 총 정리본',
#  '코로나 거리두기 2.5단계 셧다운...수도권 3단계 왜 안할까?',
#  '코로나 거리두기 격상 전이 너무 그립네요',
#  '부산 코로나 거리두기 2.5단계 내용 정리',
#  '사회적 거리두기 2단계 코로나 기준 결혼식 카페!',
#  '서울시 코로나 거리두기 3단계 격상 예고... 뭐가 달라질까?',
#  '코로나 3단계 조치 학교, 원격수업, 거리두기3단계',
#  '코로나 거리두기2단계',
#  '코로나 거리두기 3단계 격상되면? 연말 앞두고 23일부터 5명 이상 실내외 집합금지?',
#  '수도권 코로나 거리두기 1.5단계가 되었네요~',
#  '수도권 거리두기 격상_코로나 2.5단계 기준 (학교,학원,식당,카페,결혼식,헬스장 등)',
#  '코로나19 3단계 기준, 회사, 식당, 사회적 거리두기',
#  '코로나 거리두기 1단계 완화 내용 확인하세요',
#  '엄마아빠는 재택근무중 : 코로나 거리두기 2.5단계 (ㅠㅠ)',
#  '내일부터 부산까지 코로나 거리두기 2.5단계 시행']

# %%
page = urlopen("https://search.naver.com/search.naver?where=view&sm=tab_jum&query=%EC%BD%94%EB%A1%9C%EB%82%98+%EA%B1%B0%EB%A6%AC%EB%91%90%EA%B8%B0&nso=p%3Afrom20210101to20211231")
soup = BeautifulSoup(page, "html.parser")
title21 = soup.find("ul", class_ = "_list_base").find_all("a", class_="api_txt_lines")
blog21 = []
for i in range(int(len(title21))):
    text = title21[i].get_text()
    blog21.append(text)
    
blog21
# Out:
# ['코로나 거리두기 연장 헬스장 영업 카페 취식가능',
#  '코로나 거리두기 4단계 연장 개정 사적모임 최신 업데이트',
#  '코로나 사회적 거리두기 개편내용 정리',
#  '코로나 거리두기 단계별현황 4, 3단계 변경내용',
#  '코로나 거리두기 단계 별 연장내용 정리! (+4단계,3단계)',
#  '위드코로나 거리두기 수칙은 단계별로 차이가 있습니다!',
#  '추석 코로나 사회적 거리두기 수도권 4단계 가족모임 방역지침',
#  '코로나 거리두기 7월 4단계 개편안, 선별진료소 운영시간',
#  '단계별 위드코로나 거리두기 헷갈리지 말고 여기서 확인하자!',
#  "코로나19 '사회적 거리두기 강화' 국민 궁금증 5문 5답",
#  '코로나 거리두기 강화, 변경된 인원과 시간은?',
#  '코로나 거리두기 4단계..(feat.유사나 다이어트챌린지 비포애프터)',
#  '코로나 거리두기 단계, 인원제한 몇 명 까지 가능할까?',
#  '2주간 코로나 <거리두기 조정안 발표> 모임 인원, 식당 영업시간, 결혼식장 인원 제한 변경 _ 백신 도입 현황',
#  '코로나 거리두기 단계 연장, 단계별 인원 제한이 완화 되었습니다!',
#  '서울 코로나 사회적 거리 두기 4단계 개편안 2주 연장 내용 (~ 21. 10월 말)',
#  '코로나 거리두기 재실행',
#  '수도권 코로나 거리두기 4단계 연장, 업종별 달라지는 방역수칙 핵심 정리',
#  '거리두기 완화, 수도권 8명, 비수도권 10명 ?! (위드코로나)',
#  '코로나 1.5단계, 2단계 지침 알아보기 (수도권,비수도권 거리두기 하향!)',
#  '11월 위드코로나 사회적 거리두기 3차례 걸쳐 개편',
#  '코로나 거리두기 잘해야죠',
#  '12월 18일부터 코로나 거리두기 강화, 학원 식당 사적모임 등 강화 내용 정리',
#  '코로나 거리두기가 연장됩니다. 설연휴까지 2주~',
#  '12월 코로나 사회적 거리두기 단계, 일상멈춤(ft. 인원제한과 방역패스)',
#  '코로나 거리두기 연장, 청소년 방역패스 연기(ft. 영화관, 백화점)',
#  '코로나 4단계 기준 : 수도권 헬스장, 피시방, 교회, 영화관 내 사회적 거리두기',
#  '위드코로나, 사회적 거리두기 어떻게 풀리나?',
#  '코로나 거리두기',
#  '11월부터 시행되는 위드코로나 뜻과 거리두기 방식은?']

# %%
page = urlopen("https://search.naver.com/search.naver?sm=tab_hty.top&where=view&query=%EC%BD%94%EB%A1%9C%EB%82%98&oquery=%EC%BD%94%EB%A1%9C%EB%82%98+%EA%B1%B0%EB%A6%AC%EB%91%90%EA%B8%B0&tqi=hGS3Ssp0J1sssO%2B9%2BAhssssssZV-287355&nso=p%3Afrom20210101to20211231&mode=normal")
soup = BeautifulSoup(page, "html.parser")
title21 = soup.find("ul", class_ = "_list_base").find_all("a", class_="api_txt_lines")
blog21 = []
for i in range(int(len(title21))):
    text = title21[i].get_text()
    blog21.append(text)
    
blog21
# Out:
# ['코로나에대한. 백신에 대한 사족',
#  '코로나에 걸렸다 #158',
#  '코로나 자가격리 지원금 신청 후기',
#  '코로나 바이러스의 어린이 위험에 대해서',
#  '위드코로나, 재택치료, 정신줄 단단히 붙잡아야!',
#  '코로나 여행 통영 섬추천 욕지도',
#  '화이자 코로나 백신 3차 접종 후기!',
#  '코로나가 참 힘들게하네요',
#  '코로나 확진자의 일기',
#  '보라카이에서 코로나 1차 양성 확진 이후',
#  '아기 독감 백신 코로나19 백신 차이 (소아청소년 고민중)',
#  '[코로나] 현 상황에 대해서 알아보자.',
#  '청주 코로나검사 영문 PCR 음성확인서 발급 비용',
#  '코로나 검사의 원리PCR 검사와 항원 검사',
#  '코로나백신 모더나 1차 접종 부작용 후기(타이레놀 복용법)',
#  '최근 13거래일중 10거래일정도가 코로나주가 강하네요.',
#  '코로나 백신 예방접종 증명서 발급 방법 COOV',
#  '코로나 자가진단키트 정확도 및 약국 가격',
#  '코로나 백신 돌파감염과 위중증 팩트체크',
#  '코로나 확진 일기 3,4일차 (부부 코로나, 재택치료 약처방)',
#  '한국인은 모르는 코로나 최고위험상황',
#  '토요일 아침부터 코로나 검사',
#  '수도권 위드코로나 중단될까?!',
#  '코로나 자가격리지원금의 신청방법과 금액은 어떻게 될까?',
#  '코로나19. 오미크론 변이 바이러스의 대한 궁금증',
#  '코로나에 대한 개인적인 의견',
#  '자가격리 코로나 유급휴가 지원금 신청방법 (서식/필요서류)',
#  '위드코로나2단계,시행예정일은 언제?',
#  '코로나 경구용 치료제 관련주 일동제약 세종메디칼',
#  '코로나19, 오미크론 변이 바이러스에 대한 궁금증']

# %%
page = urlopen("https://search.naver.com/search.naver?where=view&query=%EC%BD%94%EB%A1%9C%EB%82%98&sm=tab_opt&nso=so%3Ar%2Cp%3Afrom20200201to20201231%2Ca%3Aall&mode=normal&main_q=&st_coll=&topic_r_cat=")
soup = BeautifulSoup(page, "html.parser")
title20 = soup.find("ul", class_ = "_list_base").find_all("a", class_="api_txt_lines")
blog20 = []
for i in range(int(len(title20))):
    text = title20[i].get_text()
    blog20.append(text)
    
blog20
# Out:
# ['코로나검사만 세번했어요ㅜㅜ',
#  '코로나와 1년살아온 경험',
#  '코로나 자가격리 (밀접접촉자, 간접 접촉자)',
#  '코로나 1.5단계 격상 임박! 코로나 1.5단계 기준은?',
#  '코로나 확진 후기,코로나 병원 입원 생활 및 가족 자가격리 후기',
#  '코로나 2.5단계 기준 결혼식 헬스장 학원 학교 등',
#  '코로나 자가격리 지원금, 대상자 기준 (feat. 해제 시간)',
#  '펌)코로나 후유증 알려진 것들 총정리',
#  '코로나 자가격리 지원금 대상 및 신청 A to Z (후기)',
#  '코로나19 확진자를 간호하며 생긴 일 [코로나 간호사 지원] - 코로나 노인 환자 간호',
#  '코로나 2.5단계 시행으로 달라지는 일상 속 규제',
#  '[기억] 코로나로 인한 내 삶의 변화...',
#  '여수 코로나 안심식당 상무 초밥 여수점',
#  '코로나시대에 안전하게 즐기는 홈캠핑',
#  '그게 저.. 코로나 때문에..',
#  '코로나19 신약 개발을 둘러싼 궁금증',
#  '코로나19 시대의 세계 유명 미술관 모습',
#  '코로나이후 수집지각변동설',
#  '코로나19 세계의 크리스마스 모습들',
#  '저 코로나 검사했어요',
#  '코로나19 백신의 원료?! 상어의 간유, 스쿠알렌',
#  '코로나가 진짜 위험한 병일까요??',
#  '코로나 치과치료는 괜찮을까? 안심 방역 CCL만 믿으세요',
#  '코로나 방역보다 더 중요한 기레기 방역',
#  '코로나가 우리 가족에게 미친 영향',
#  '코로나로 바뀐 한해!',
#  '코로나19에 맞서 몸도 마음도 건강히! 셀프 메디케이션',
#  '에효ㅠㅠ 코로나!!',
#  '코로나 CJ CGV 주가를 봤더니...',
#  '포스트 코로나 시대의 화장실 디자인']

# %%
from konlpy.tag import Okt #형태소 분석을 위한 클래스 
from konlpy.corpus import kolaw #샘플 예제를 가져오기 위한(kolaw : 우리나라 헌법)
import nltk
from wordcloud import WordCloud #아까 import해서 안해도 되지만 처음 쓰는 경우 이걸 import해야함

# %%
okt = Okt()
text20 = []
for i in range(int(len(blog20))):
    noun = okt.nouns(blog20[i])
    for j in noun:
        text20.append(j)
text20
# Out:
# ['코로나',
#  '검사',
#  '세번',
#  '코로나',
#  '경험',
#  '코로나',
#  '자가',
#  '격리',
#  '밀접',
#  '접촉',
#  '간접',
#  '접촉',
#  '코로나',
#  '단계',
#  '격상',
#  '임박',
#  '코로나',
#  '단계',
#  '기준',
#  '코로나',
#  '확진',
#  '후기',
#  '코로나',
#  '병원',
#  '입원',
#  '생활',
#  '및',
#  '가족',
#  '자가',
#  '격리',
#  '후기',
#  '코로나',
#  '단계',
#  '기준',
#  '결혼식',
#  '헬스장',
#  '학원',
#  '학교',
#  '등',
#  '코로나',
#  '자가',
#  '격리',
#  '원금',
#  '대상자',
#  '기준',
#  '해제',
#  '시간',
#  '펌',
#  '코로나',
#  '후유증',
#  '것',
#  '정리',
#  '코로나',
#  '자가',
#  '격리',
#  '원금',
#  '대상',
#  '및',
#  '신청',
#  '후기',
#  '코로나',
#  '확',
#  '진자',
#  '간호',
#  '일',
#  '코로나',
#  '간호사',
#  '지원',
#  '코로나',
#  '노인',
#  '환자',
#  '간호',
#  '코로나',
#  '단계',
#  '시행',
#  '일상',
#  '속',
#  '규제',
#  '기억',
#  '코로나',
#  '내',
#  '삶',
#  '변화',
#  '여수',
#  '코로나',
#  '안심',
#  '식당',
#  '상무',
#  '초밥',
#  '점',
#  '코로나',
#  '시대',
#  '홈',
#  '캠핑',
#  '그게',
#  '저',
#  '코로나',
#  '때문',
#  '코로나',
#  '신약',
#  '개발',
#  '궁금증',
#  '코로나',
#  '시대',
#  '세계',
#  '유명',
#  '미술관',
#  '모습',
#  '코로나',
#  '이후',
#  '수집',
#  '지각',
#  '변동',
#  '설',
#  '코로나',
#  '세계',
#  '크리스마스',
#  '모습',
#  '저',
#  '코로나',
#  '검사',
#  '코로나',
#  '백신',
#  '원료',
#  '상어',
#  '간유',
#  '스쿠알렌',
#  '코로나',
#  '진짜',
#  '병',
#  '요',
#  '코로나',
#  '치과',
#  '치료',
#  '안심',
#  '방역',
#  '만',
#  '코로나',
#  '방역',
#  '더',
#  '기레기',
#  '방역',
#  '코로나',
#  '우리',
#  '가족',
#  '영향',
#  '코로나',
#  '한해',
#  '코로나',
#  '몸',
#  '마음',
#  '셀프',
#  '메',
#  '디케이',
#  '션',
#  '효',
#  '코로나',
#  '코로나',
#  '주가',
#  '포스트',
#  '코로나',
#  '시대',
#  '화장실',
#  '디자인']

# %%
okt = Okt()
text20 = []
for i in range(int(len(blog20))):
    noun = okt.nouns(blog20[i])
    for j in noun:
        text20.append(j)
text20

# %%
#### 빈도수 처리(워드 카운팅)

#nltk : 빈도를 계산해서 정렬까지 시켜주는 

ko = nltk.Text(text20, name="코로나2020")
#이름 넣어야 되는데 아무거나 지정하면 됨

#dir(ko) >> 사용할 수 있는 함수 조회

data = ko.vocab().most_common(100)
#얘는 빈도를 비율로 나타낸건 아니고 실제 counting 수 확인
data
# Out:
# [('코로나', 34),
#  ('자가', 4),
#  ('격리', 4),
#  ('단계', 4),
#  ('기준', 3),
#  ('후기', 3),
#  ('시대', 3),
#  ('방역', 3),
#  ('검사', 2),
#  ('접촉', 2),
#  ('및', 2),
#  ('가족', 2),
#  ('원금', 2),
#  ('간호', 2),
#  ('안심', 2),
#  ('저', 2),
#  ('세계', 2),
#  ('모습', 2),
#  ('세번', 1),
#  ('경험', 1),
#  ('밀접', 1),
#  ('간접', 1),
#  ('격상', 1),
#  ('임박', 1),
#  ('확진', 1),
#  ('병원', 1),
#  ('입원', 1),
#  ('생활', 1),
#  ('결혼식', 1),
#  ('헬스장', 1),
#  ('학원', 1),
#  ('학교', 1),
#  ('등', 1),
#  ('대상자', 1),
#  ('해제', 1),
#  ('시간', 1),
#  ('펌', 1),
#  ('후유증', 1),
#  ('것', 1),
#  ('정리', 1),
#  ('대상', 1),
#  ('신청', 1),
#  ('확', 1),
#  ('진자', 1),
#  ('일', 1),
#  ('간호사', 1),
#  ('지원', 1),
#  ('노인', 1),
#  ('환자', 1),
#  ('시행', 1),
#  ('일상', 1),
#  ('속', 1),
#  ('규제', 1),
#  ('기억', 1),
#  ('내', 1),
#  ('삶', 1),
#  ('변화', 1),
#  ('여수', 1),
#  ('식당', 1),
#  ('상무', 1),
#  ('초밥', 1),
#  ('점', 1),
#  ('홈', 1),
#  ('캠핑', 1),
#  ('그게', 1),
#  ('때문', 1),
#  ('신약', 1),
#  ('개발', 1),
#  ('궁금증', 1),
#  ('유명', 1),
#  ('미술관', 1),
#  ('이후', 1),
#  ('수집', 1),
#  ('지각', 1),
#  ('변동', 1),
#  ('설', 1),
#  ('크리스마스', 1),
#  ('백신', 1),
#  ('원료', 1),
#  ('상어', 1),
#  ('간유', 1),
#  ('스쿠알렌', 1),
#  ('진짜', 1),
#  ('병', 1),
#  ('요', 1),
#  ('치과', 1),
#  ('치료', 1),
#  ('만', 1),
#  ('더', 1),
#  ('기레기', 1),
#  ('우리', 1),
#  ('영향', 1),
#  ('한해', 1),
#  ('몸', 1),
#  ('마음', 1),
#  ('셀프', 1),
#  ('메', 1),
#  ('디케이', 1),
#  ('션', 1),
#  ('효', 1)]

# %%
### 워드 클라우드 출력
import matplotlib.pyplot as plt
wc=WordCloud(max_font_size=40, background_color = "white",max_words=200, 
             font_path="C:/Windows/Fonts/malgun.ttf").generate_from_frequencies(dict(data))

#stopwords쓸수 없음
#그냥 generate쓸 수 없음
#generate_from_frequencies할 때 데이터는 dict형태로 넘겨줘야 함
#원래 형식이 tuple로 되어있음

plt.figure(figsize=(12,12))
plt.imshow(wc, interpolation = "bilinear")
#image를 불러올 때 WordCloud의 recolor함수 사용해서 색깔 불러오기
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
news21 = []
list = ["https://search.naver.com/search.naver?where=news&query=%EC%BD%94%EB%A1%9C%EB%82%9819&sm=tab_opt&sort=0&photo=4&field=0&pd=3&ds=2021.04.01&de=2021.04.30&docid=&related=0&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so%3Ar%2Cp%3Afrom20210401to20210430&is_sug_officeid=0",
"https://search.naver.com/search.naver?where=news&sm=tab_pge&query=%EC%BD%94%EB%A1%9C%EB%82%9819&sort=0&photo=4&field=0&pd=3&ds=2021.04.01&de=2021.04.30&cluster_rank=10&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so:r,p:from20210401to20210430,a:all&start=11",
"https://search.naver.com/search.naver?where=news&sm=tab_pge&query=%EC%BD%94%EB%A1%9C%EB%82%9819&sort=0&photo=4&field=0&pd=3&ds=2021.04.01&de=2021.04.30&cluster_rank=20&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so:r,p:from20210401to20210430,a:all&start=21",
"https://search.naver.com/search.naver?where=news&sm=tab_pge&query=%EC%BD%94%EB%A1%9C%EB%82%9819&sort=0&photo=4&field=0&pd=3&ds=2021.04.01&de=2021.04.30&cluster_rank=30&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so:r,p:from20210401to20210430,a:all&start=31",
"https://search.naver.com/search.naver?where=news&sm=tab_pge&query=%EC%BD%94%EB%A1%9C%EB%82%9819&sort=0&photo=4&field=0&pd=3&ds=2021.04.01&de=2021.04.30&cluster_rank=40&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so:r,p:from20210401to20210430,a:all&start=41",
"https://search.naver.com/search.naver?where=news&sm=tab_pge&query=%EC%BD%94%EB%A1%9C%EB%82%9819&sort=0&photo=4&field=0&pd=3&ds=2021.04.01&de=2021.04.30&cluster_rank=50&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so:r,p:from20210401to20210430,a:all&start=51",
"https://search.naver.com/search.naver?where=news&sm=tab_pge&query=%EC%BD%94%EB%A1%9C%EB%82%9819&sort=0&photo=4&field=0&pd=3&ds=2021.04.01&de=2021.04.30&cluster_rank=61&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so:r,p:from20210401to20210430,a:all&start=61",
"https://search.naver.com/search.naver?where=news&sm=tab_pge&query=%EC%BD%94%EB%A1%9C%EB%82%9819&sort=0&photo=4&field=0&pd=3&ds=2021.04.01&de=2021.04.30&cluster_rank=71&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so:r,p:from20210401to20210430,a:all&start=71"]

for li in list:
    page = urlopen(li)
    soup = BeautifulSoup(page, "html.parser")
    title21 = soup.find("ul", class_ = "list_news").find_all("a", class_="news_tit")
    for i in range(int(len(title21))):
        text = title21[i].get_text()
        news21.append(text)
    
news21
# Out:
# ['닐슨IQ 코리아, 포스트 코로나19 시대 소비 지형 변화 발표',
#  '타코닉 바이오사이언스, 새로운 코로나19 마우스 모델 출시',
#  '노원구서비스공단, 코로나19 백신접종센터 운영 총력',
#  '코로나로 취소된 ‘양구곰취축제’, 온라인축제로 풍성',
#  '알릭스파트너스, 코로나19 이후 소비자 구매 우선순위 변화상 발표',
#  '코로나19 항체 치료제 국내 대량생산을 위한 국제 콘퍼런스 개최',
#  '[코로나19] 이틀째 730명대 확진···예방접종은 더디기만',
#  "[issue&] 코로나 사태 속에서도 적극적 인재 확보 적시적소 배치 위해 '상시 ...",
#  '서울특별시립청소년활동진흥센터, ‘코로나 시대 1년, 미래 청소년 활동 전환...',
#  '[비즈스토리] 코로나19 중증 고위험군 환자 대상 ‘나파벨탄’ 임상 3상 계획...',
#  "스타튜브 코로나19 극복을 위한 '야한식당' 시즌1 성황리에 종료",
#  '북랩, 코로나 시대 교회의 타락을 경고한 ‘종이냐 자유인이냐’ 출간',
#  '코로나19 확진자 다시 700명대로···4차 대유행 시작?',
#  'Momentum Labs, 코로나19 기간 글로벌 업체들 위한 최신 브랜드 인지 및 충성...',
#  'PRA Health Sciences, 승인 획득한 백신과 치료제에 대한 약물감시 솔루션 통...',
#  '국내 코로나19 신규확진자 671명',
#  'NDS, 의료 기관 출입 번거로움 줄이는 ‘코로나 QR 출입증’ 무료 배포',
#  '서울숲공원, 위드코로나 시대 틱톡과 식목일 챌린지 이벤트 진행',
#  '[식음료 특집]‘건강 기능성’에 ‘편리미엄’ 더한 코로나 극복의 든든한 지...',
#  '[2021 국가산업대상] 코로나19 백신·치료제에 대한 임상시험 진행',
#  '[2021 국가산업대상] 개인 채무 감면, 코로나19 피해기업 투자 단행',
#  '열매나눔재단, 코로나19 타격 소상공인에 1.8% 저금리 대출 지원',
#  '에스엘에스바이오, 객담 검사 코로나19 항원 신속진단키트 유럽 수출 추진',
#  '벼룩시장구인구직 조사: 코로나19 탓 소득 감소, 직장인 10명 중 8명 ‘투잡 ...',
#  '용인정신병원, ‘코로나 시대 정신의학의 현실과 나아갈 길’ 심포지엄 성황리...',
#  '판촉물 쇼핑몰 ‘키위스타 스토어’ 오픈, 코로나19 관련 위생용품 판매',
#  '공공 경보시스템 전문가들, 에버브릿지의 코로나19 행사 ‘회복으로의 길’ 리...',
#  '한국자활복지개발원, 코로나19 대응 ‘내일키움일자리’ 사업 성공적 마무리',
#  '에리카헤어, 코로나19 팬데믹 속 지점 늘린 비결 공개',
#  "식약처, 한번 맞는 코로나 백신 한국얀센 '코비드-19백신 얀센주' 품목허가",
#  '서울문화재단 시민청, 코로나19로 지친 시민 위로하기 위한 문화예술 프로그램...',
#  '마시모, O3® 통해 코로나19 환자들의 대뇌 산소투여에 대한 호흡기 구급 치료...',
#  '충남연구원, 서산의료원에 코로나19 지원 물품 전달',
#  '임팩트피플스: 신중년의 코로나 언택트 활동 1위는 등산',
#  '협성대 IPP센터, 코로나 확산 대비 장기현장실습 비대면 모집 강화',
#  '열매나눔재단, 코로나 여파 결식 학생에 2년째 식품꾸러미 지원',
#  '온·오프라인 동시에 즐기는 국내 최대 어린이 지식축제 ‘제19회 파주출판도...',
#  '성신여대, 반기문 전 UN 사무총장 초청 강연 진행',
#  '코로나19 혈장치료제 개발 얼라이언스, NIH 후원 연구용 코로나19 고면역성 글...',
#  'S-Oil, 청년 푸드트럭에 유류비 1억원',
#  '문 대통령 지지율, 30%선도 무너졌다',
#  '함께하는 한숲, 지역사회 소외계층에 코로나바이러스감염증-19 감염 예방 위한...',
#  '삼성전자, 2021년 1분기 실적 발표',
#  '신한카드, IKEA 멤버십 PLCC 출시',
#  '휴머니젠, DLBCL환자 대상으로 렌질루맙을 CAR-T세포 치료제와 병용한 ZUMA-1...',
#  '예스24: ‘북튜브’의 진화, 더 깊숙한 책의 세계로',
#  '씨넥스존, 로지텍 화상회의 전문 온라인 스토어 론칭',
#  "미담장학회, 'UNIST, 아람코코리아'와 교육격차 해소 위한 협약식 체결",
#  '[기업이 힘이다!] B tv 패밀리, 가정의 달 부모님 선물로 제격',
#  'KB국민은행, 5억달러 규모 ‘지속가능채권’ 발행',
#  '홍남기 "현행 사회적 거리두기·5인 사적모임 금지 3주간 연장"',
#  'Momentum Labs, 2021년 5월 PaaS솔루션 선보일 계획',
#  '한국자활복지개발원, 사회적 경제 기업 금융 지원을 위한 업무 협약 체결',
#  'GC녹십자, 1분기 실적 발표',
#  '대한체육회 진로지원센터, 이전 개소식 및 선수 간담회 개최',
#  '군포시청소년재단, 관내 청소년 위해 유휴공간을 스터디 공간으로 운영',
#  '유니온팝, 비대면 시대 XR 활용한 K-POP 온택트 콘서트 진행',
#  'SAP 코리아 “인적 경험 관리가 인사 혁신의 미래”',
#  '[기업이 힘이다!] 변신하는 지능형 지상 이동 로봇 선보여',
#  '‘위기니까 더욱 더’ 꿈나무에 투자하는 기업들',
#  '트래볼루션, 관광기업 혁신바우처 사업 ‘공급기업’ 선정',
#  '피앤유드론, 대한항공과 업무협약 체결로 글로벌 드론시장 공략 가속도',
#  '[기업이 힘이다!] 세계 최대 규모 액화수소 공장 건립 추진',
#  '[기업이 힘이다!] 5년간 18조원 투자, 수소 생태계 조성 앞장',
#  '행복나눔재단, 인천남부교육지원청-상상인그룹과 청각장애 학생 학습 지원 협...',
#  '[기업이 힘이다!] 신성장동력 육성, ESG·상생 경영으로 경제 회복 견인',
#  '[기업이 힘이다!] 협력사와 동반성장 위한 상생프로그램 운영',
#  '[기업이 힘이다!] 어린이집 새단장 … 그룹 직원 자녀들도 혜택',
#  '서울문화재단, ‘제8회 시민청 도시사진전’ 참여 작품 공모',
#  '동국제강, 노사 27년 연속 평화적 임금협상 타결',
#  '손예진 인테리어’ 토탈 인테리어 브랜드 ‘영림’ 첫 TV-CF 온에어',
#  '[기업이 힘이다!] 온·오프라인 유통 채널로 중소기업 판로 지원',
#  '[기업이 힘이다!] 협력사와 지속 성장 위한 ‘상생의 선순환’에 힘 싣는다',
#  '한국인공지능협회-참여 기업, 서울형 뉴딜 일자리 AI 학습 데이터 구축사업 인...',
#  '공주시 - 박물관에서의 1박2일…온라인으로 떠나는 구석기축제',
#  '대구광역시 - ‘시민참여형 방역’ 앞장…생활방역 안착 모범 보여',
#  '부산광역시 - 소상공인에 무한도·무신용·무이자 ‘3무 특별자금’',
#  '[분양포커스] 스페인풍 럭셔리 타운하우스 … 제주 별장서 골프 즐기며 힐링',
#  '사회복지협의회 - 대학 동아리 멘토링 프로그램으로 ‘행복한국 운동’ 첫발',
#  '한국가스공사 - 버려지던 LNG 냉열 에너지, 데이터센터 가동 등 활용']

# %%
okt = Okt()
text21 = []
for i in range(int(len(news21))):
    noun = okt.nouns(news21[i])
    for j in noun:
        text21.append(j)
text21

#### 불용어 처리

#불용어 사전 만들기
stop_words = ["확", "진자", "위로", "소", "전북도", "종","위","로","번","재","위해"]

#아까는 함수가 있었지만 이건 없으므로 반복문 돌려서 매칭해서 원본에 담을 수 있게 해야 함

text21 = [each_word for each_word in text21 if each_word not in stop_words]
print(len(text21))

#### 빈도수 처리(워드 카운팅)

#nltk : 빈도를 계산해서 정렬까지 시켜주는 

ko = nltk.Text(text21, name="코로나2021뉴스")
#이름 넣어야 되는데 아무거나 지정하면 됨

#dir(ko) >> 사용할 수 있는 함수 조회

data = ko.vocab().most_common(100)
#얘는 빈도를 비율로 나타낸건 아니고 실제 counting 수 확인
data
#data = data[:10]

### 워드 클라우드 출력
import matplotlib.pyplot as plt
wc=WordCloud(max_font_size=100, background_color = "white",max_words=40, 
             font_path="C:/Windows/Fonts/malgun.ttf").generate_from_frequencies(dict(data))

#stopwords쓸수 없음
#그냥 generate쓸 수 없음
#generate_from_frequencies할 때 데이터는 dict형태로 넘겨줘야 함
#원래 형식이 tuple로 되어있음

plt.figure(figsize=(10,10))
plt.imshow(wc, interpolation = "bilinear")
#image를 불러올 때 WordCloud의 recolor함수 사용해서 색깔 불러오기
plt.axis("off")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 okt = Okt()
#       2 text21 = []
#       3 for i in range(int(len(news21))):
#
# NameError: name 'Okt' is not defined

# %%
data
# Out:
# [('코로나', 60),
#  ('명', 19),
#  ('확진', 11),
#  ('대응', 9),
#  ('방역', 9),
#  ('극복', 9),
#  ('누적', 7),
#  ('경북', 5),
#  ('신규', 5),
#  ('개최', 5),
#  ('운영', 5),
#  ('추가', 4),
#  ('파주시', 4),
#  ('발생', 4),
#  ('지원', 4),
#  ('위', 4),
#  ('대구시', 3),
#  ('로', 3),
#  ('온라인', 3),
#  ('번', 3),
#  ('관리', 3),
#  ('참여', 3),
#  ('용인시', 3),
#  ('백신', 3),
#  ('점검', 3),
#  ('성남시', 2),
#  ('시민', 2),
#  ('보건소', 2),
#  ('비대', 2),
#  ('영주시', 2),
#  ('재', 2),
#  ('검사', 2),
#  ('문화', 2),
#  ('임시', 2),
#  ('음성군', 2),
#  ('음성', 2),
#  ('국민', 2),
#  ('위해', 2),
#  ('민생', 2),
#  ('경제', 2),
#  ('부산시', 2),
#  ('소상', 2),
#  ('공인', 2),
#  ('준비', 2),
#  ('포항시', 2),
#  ('속보', 2),
#  ('이후', 2),
#  ('예산', 2),
#  ('확대', 2),
#  ('곳', 2),
#  ('교육', 2),
#  ('체계', 2),
#  ('부시장', 2),
#  ('특별', 2),
#  ('접종', 2),
#  ('확산', 2),
#  ('보건', 2),
#  ('속', 1),
#  ('더욱', 1),
#  ('별', 1),
#  ('기부', 1),
#  ('백서', 1),
#  ('권', 1),
#  ('발간', 1),
#  ('안전', 1),
#  ('자료', 1),
#  ('활용', 1),
#  ('현', 1),
#  ('거리', 1),
#  ('두기', 1),
#  ('주간', 1),
#  ('유지', 1),
#  ('총력', 1),
#  ('목포시', 1),
#  ('격려', 1),
#  ('마음', 1),
#  ('계속', 1),
#  ('장수군', 1),
#  ('무식', 1),
#  ('시무', 1),
#  ('자영', 1),
#  ('업자', 1),
#  ('돕기', 1),
#  ('영동', 1),
#  ('곶감', 1),
#  ('축제', 1),
#  ('판매', 1),
#  ('중심', 1),
#  ('보성군', 1),
#  ('핵심', 1),
#  ('리부트', 1),
#  ('보성', 1),
#  ('발표', 1),
#  ('이전', 1),
#  ('시동', 1),
#  ('녹십자', 1),
#  ('의료', 1),
#  ('재단', 1),
#  ('및', 1),
#  ('광주시', 1)]

# %%
news20 = []
list = ["https://search.naver.com/search.naver?where=news&sm=tab_pge&query=%EC%BD%94%EB%A1%9C%EB%82%98&sort=0&photo=4&field=0&pd=3&ds=2020.03.03&de=2020.10.29&cluster_rank=10&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so:r,p:from20200303to20201029,a:all&start=11",
       "https://search.naver.com/search.naver?where=news&sm=tab_pge&query=%EC%BD%94%EB%A1%9C%EB%82%98&sort=0&photo=4&field=0&pd=3&ds=2020.03.03&de=2020.10.29&cluster_rank=20&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so:r,p:from20200303to20201029,a:all&start=51",
       "https://search.naver.com/search.naver?where=news&sm=tab_pge&query=%EC%BD%94%EB%A1%9C%EB%82%98&sort=0&photo=4&field=0&pd=3&ds=2020.03.03&de=2020.10.29&cluster_rank=40&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so:r,p:from20200303to20201029,a:all&start=101",
       "https://search.naver.com/search.naver?where=news&sm=tab_pge&query=%EC%BD%94%EB%A1%9C%EB%82%98&sort=0&photo=4&field=0&pd=3&ds=2020.03.03&de=2020.10.29&cluster_rank=50&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so:r,p:from20200303to20201029,a:all&start=141",
       "https://search.naver.com/search.naver?where=news&sm=tab_pge&query=%EC%BD%94%EB%A1%9C%EB%82%98&sort=0&photo=4&field=0&pd=3&ds=2020.03.03&de=2020.10.29&cluster_rank=60&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so:r,p:from20200303to20201029,a:all&start=191",
       "https://search.naver.com/search.naver?where=news&sm=tab_pge&query=%EC%BD%94%EB%A1%9C%EB%82%98&sort=0&photo=4&field=0&pd=3&ds=2020.03.03&de=2020.10.29&cluster_rank=70&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so:r,p:from20200303to20201029,a:all&start=241"]
for li in list:
    page = urlopen(li)
    soup = BeautifulSoup(page, "html.parser")
    title20 = soup.find("ul", class_ = "list_news").find_all("a", class_="news_tit")
    for i in range(int(len(title21))):
        text = title20[i].get_text()
        news20.append(text)
    
news20
# Out:
# ['[비즈스토리] 코로나 사태 장기화 … 직원들의 ‘마음 건강’ 챙기기 나섰다',
#  '비즈니스북스, ‘세계미래보고서 2021’ 포스트 코로나 특별판 출간',
#  '[2020 소비자의 선택] 지속적인 제품 개발과 혁신코로나 위기 속에도 빛났다',
#  '[시선집중 施善集中] 코로나로 인한 혈액 수급 위기 ‘사랑 나눔 헌혈 캠페인...',
#  '티앤알바이오팹 등 산학연구팀, 인간 역분화줄기세포 유래 심근세포 활용 코로...',
#  '코로나 시대, 숲에서 받은 위로와 감동을 나누는 ‘서울숲 에피소드 공모전’...',
#  '마이크로스트레티지코리아, 코로나19 극복 위해 ‘노인복지센터’에 후원품 지...',
#  '힐튼 이펙트 재단, 2020년 지원금 수령 단체 공개 및 코로나19 대응 누적 지원...',
#  'GC녹십자, 코로나19 혈장치료제 추가 생산 완료',
#  '냉동식품서 첫 검출된 코로나19 바이러스, 해결방안은?',
#  '우옥영 사단법인 보건교육포럼 이사장, 코로나19 극복 위한 ‘스테이 스트롱 ...',
#  '에버브리지의 ‘코로나-19 R2R: 회복에 이르는 길’ 심포지엄 첫째 날 미국 4...',
#  'SK텔레콤, 말로 하는 AI 상담 서비스 ‘보이스봇’ 업계 첫 선',
#  '[비즈스토리] 코로나 블루 물럿거라 ! 창립 40돌 기념 ‘랜선패밀리콘서트’',
#  '한전, 글로벌 에너지엑스포 ‘BIXPO 2020’ 온라인 전시회 개최',
#  '코로나 블루 ‘마인드풀 위크’로 마음 다스리기',
#  '배우 김유정, 1억원 이상 기부자 클럽 최연소 가입',
#  '마인드풀니스 기반 커뮤니티 플랫폼 마인드라운드, 코로나블루 극복 음악명상...',
#  '신한카드, 항균필름 카드 플레이트 도입',
#  'KB국민은행, 5억달러 규모 후순위 지속가능채권 발행',
#  '국립나주병원, 코로나19 게임 과몰입 해결 위해 나선다',
#  '오렌지라이프 정문국 사장, 코로나19 극복 위한 ‘플라워 버킷 챌린지’ 참여',
#  '강동구청소년지원센터 꿈드림, 포스트 코로나19 극복 ‘청소년 힐링 프로젝트...',
#  '입소스 “포스트 코로나, 세계인 10명 중 9명은 공평하고 지속 가능한 시대 갈...',
#  '전시와 전통예술, 과거와 현재를 잇는 융합 공연 2020 디 아트 스팟 시리즈 ‘...',
#  '“코로나 극복 응원”… 롯데월드타워, 일곱 색깔 희망의 무지개',
#  '[issue&] 언택트 과학교실, 임직원 성금 … 코로나 사태에도 지속적 사회공헌...',
#  '‘결식계층 제로 사회’ 목표로 활동 코로나19-폭우 피해지 긴급 지원',
#  '토닥토닥 ‘나비포옹법’을 아시나요?… 코로나 우울 함께 위로합니다',
#  '소상공인에 코로나 피해 복구 긴급자금 3조원 지원',
#  '건국대 창업지원단, 한국전자기술연구원과 산학연 협력체계 구축 MOU 체결',
#  '민주화운동기념사업회, 세계 민주주의의 날 맞아 ‘코로나19와 민주주의의 위...',
#  '제12회 서울청소년창의서밋, 코로나19가 불러온 사회적 거리와 연결 새로운 ‘...',
#  '코로나 시대, 타인에 대한 인류의 두려움을 탐구하는 세계적 석학의 지혜로운...',
#  '웨스턴 유니온 재단, 코로나19로 타격받은 유학생들 지원',
#  '“코로나 이후 준비” 한국사회투자, 소셜벤처 위한 언택트 홍보 마케팅 서비...',
#  '용산 아이파크몰 영창뮤직, 피아노 및 커즈와일 디지털피아노 서프라이즈 할인',
#  '피플앤드테크놀러지, 코로나19 대응 위한 ‘스마트 감염관리 시스템’ 출시',
#  '쌍용자동차, 2020년 3분기 경영 실적 발표',
#  'GS25, 코로나19 뉴노멀 시대에 국내외 유명 먹거리 프레시푸드 상품 개발 확대',
#  '소셜혁신연구소, 유네스코 ESD 인증 ‘소셜벤처 스타트스쿨’ 전국 중고등학교...',
#  '금천구시설관리공단, 코로나19 확산 방지에 기여한 우수 사회복무요원에 표창',
#  '[시선집중] 코로나19 시대, 하나님의 소망 메시지 담아',
#  '경기도교육청, 전국 최초 코로나19·경계존중 교육·디지털 성폭력 예방·기후...',
#  'GC녹십자, 코로나19 혈장 치료제 임상 2상 승인',
#  '프로스트 앤드 설리번 “포스트 코로나 시대 글로벌 보안 산업이 서비스 기반...',
#  '좋은땅출판사, ‘당신 꼭 행복하세요’ 출간',
#  '현대자동차, 2020년 3분기 경영실적 발표',
#  '서울문화재단, 코로나19로 침체한 예술계에 ‘온라인 미디어 예술활동’ 30억...',
#  '미래엔, ‘온라인 수업 서비스 위한 설문’… 교사 70% 포스트 코로나 시대 새...',
#  '사노피 초록산타, 코로나19 극복에 힘쓰는 의료진 격려 위한 ‘덕분에 챌린지...',
#  '한전KDN, 성과급 일부 상품권으로 지급… 코로나19 극복에 동참',
#  "해남군, 코로나19 예방 최선은 '마스크 착용·개인위생' 철저",
#  '[시선집중] 신나는 달리기 축제 ‘기브앤 레이스 버추얼 런’…코로나19 어려...',
#  '금천구시설관리공단, 코로나19 극복 위한 ‘사랑의 헌혈 행사’ 진행',
#  '아방스 클리니컬, 아토사 테라퓨틱스의 두 번째 코로나19 치료제 개발 프로그...',
#  '나주시, 코로나19 예방 위한 비대면 금연 클리닉',
#  "수원시, 외식환경 제공하는 '코로나19 안심식당' 참여업소 모집",
#  '비딩스테이, 코로나19 속 모임 및 행사 온·오프라인 동시 진행 솔루션 ‘온오...',
#  '지티지웰니스, 코로나19 속 안전한 문화·예술 공연 지원 나서']

# %%
okt = Okt()
text20 = []
for i in range(int(len(news20))):
    noun = okt.nouns(news20[i])
    for j in noun:
        text20.append(j)
text20

#### 불용어 처리

#불용어 사전 만들기
stop_words = ["위","제","속","및","로"]

#아까는 함수가 있었지만 이건 없으므로 반복문 돌려서 매칭해서 원본에 담을 수 있게 해야 함

text20 = [each_word for each_word in text20 if each_word not in stop_words]
print(len(text20))

#### 빈도수 처리(워드 카운팅)

#nltk : 빈도를 계산해서 정렬까지 시켜주는 

ko = nltk.Text(text20, name="코로나2020뉴스")
#이름 넣어야 되는데 아무거나 지정하면 됨

#dir(ko) >> 사용할 수 있는 함수 조회

data = ko.vocab().most_common(100)
#얘는 빈도를 비율로 나타낸건 아니고 실제 counting 수 확인
data
#data = data[:10]

### 워드 클라우드 출력
import matplotlib.pyplot as plt
wc=WordCloud(max_font_size=100, background_color = "white",max_words=40, 
             font_path="C:/Windows/Fonts/malgun.ttf").generate_from_frequencies(dict(data))

#stopwords쓸수 없음
#그냥 generate쓸 수 없음
#generate_from_frequencies할 때 데이터는 dict형태로 넘겨줘야 함
#원래 형식이 tuple로 되어있음

plt.figure(figsize=(10,10))
plt.imshow(wc, interpolation = "bilinear")
#image를 불러올 때 WordCloud의 recolor함수 사용해서 색깔 불러오기
plt.axis("off")
# Out:
# 558
# (-0.5, 399.5, 199.5, -0.5)

# %%
data
# Out:
# [('코로나', 47),
#  ('극복', 9),
#  ('시대', 7),
#  ('지원', 6),
#  ('포스트', 5),
#  ('사회', 5),
#  ('세계', 4),
#  ('지속', 4),
#  ('개발', 3),
#  ('시선집중', 3),
#  ('치료', 3),
#  ('서비스', 3),
#  ('블루', 3),
#  ('온라인', 3),
#  ('마인드', 3),
#  ('소셜', 3),
#  ('관리', 3),
#  ('예방', 3),
#  ('예술', 3),
#  ('비즈', 2),
#  ('스토리', 2),
#  ('사태', 2),
#  ('직원', 2),
#  ('마음', 2),
#  ('간', 2),
#  ('혁신', 2),
#  ('위기', 2),
#  ('사랑', 2),
#  ('헌혈', 2),
#  ('산학', 2),
#  ('위로', 2),
#  ('위해', 2),
#  ('센터', 2),
#  ('재단', 2),
#  ('대응', 2),
#  ('녹십자', 2),
#  ('혈장', 2),
#  ('첫', 2),
#  ('해결', 2),
#  ('교육', 2),
#  ('스테이', 2),
#  ('날', 2),
#  ('기념', 2),
#  ('한전', 2),
#  ('글로벌', 2),
#  ('풀', 2),
#  ('니스', 2),
#  ('기반', 2),
#  ('린지', 2),
#  ('참여', 2),
#  ('청소년', 2),
#  ('명', 2),
#  ('중', 2),
#  ('공연', 2),
#  ('언택트', 2),
#  ('임', 2),
#  ('활동', 2),
#  ('피해', 2),
#  ('긴급', 2),
#  ('민주주의', 2),
#  ('서울', 2),
#  ('온', 2),
#  ('처', 2),
#  ('피아노', 2),
#  ('디지털', 2),
#  ('앤드', 2),
#  ('자동차', 2),
#  ('경영', 2),
#  ('실적', 2),
#  ('발표', 2),
#  ('전국', 2),
#  ('금천구', 2),
#  ('시설', 2),
#  ('공단', 2),
#  ('행사', 2),
#  ('진행', 2),
#  ('클리', 2),
#  ('장기', 1),
#  ('건강', 1),
#  ('비즈니스', 1),
#  ('북스', 1),
#  ('미래', 1),
#  ('보고서', 1),
#  ('특별판', 1),
#  ('소비자', 1),
#  ('선택', 1),
#  ('제품', 1),
#  ('혈액', 1),
#  ('수급', 1),
#  ('나눔', 1),
#  ('캠페인', 1),
#  ('티앤', 1),
#  ('알바', 1),
#  ('팹', 1),
#  ('등', 1),
#  ('연구', 1),
#  ('팀', 1),
#  ('인간', 1),
#  ('역', 1),
#  ('분화', 1)]
